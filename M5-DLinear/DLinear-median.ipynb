# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip3 install thop
# Out:
# Requirement already satisfied: thop in /usr/local/lib/python3.10/dist-packages (0.1.1.post2209072238)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from thop) (2.5.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->thop) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->thop) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->thop) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->thop) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->thop) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch->thop) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch->thop) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->thop) (3.0.2)

# %%
import os
import numpy as np
import pandas as pd
import torch
from torch.utils.data import Dataset
from sklearn.preprocessing import StandardScaler
import os, sys, gc, time, warnings, pickle, psutil, random
warnings.filterwarnings('ignore')

class Config(object):
  def __init__(self, args):
    #basic config
    self.is_training = args.get('is_training', 1)
    self.model_id = args.get('model_id', 'test')
    self.model = args.get('model', 'Autoformer')
    #dataloader
    self.train_data = args.get('train_data', 0.7)
    self.data = args.get('data', 'test')
    self.root_path = args.get('root_path', '/content/drive/MyDrive/M5-FITS/processed-nonparam')
    self.data_path = args.get('data_path', 'm5.csv')
    self.features = args.get('features', 'S')
    self.target = args.get('target', 'sales')
    self.freq = args.get('freq', 'd')
    self.scale = args.get('scale', True)
    self.checkpoints = args.get('checkpoints', '/content/drive/MyDrive/M5-FITS/checkpoints')
    #forecasting
    self.seq_len = args.get('seq_len', 56)
    self.pred_len = args.get('pred_len', 28)
    self.label_len = args.get('label_len', 28)
    self.individual = args.get('individual', False)
    #optimization
    self.num_workers = args.get('num_workers', 10)
    self.itr = args.get('itr', 2)
    self.train_epochs = args.get('train_epochs', 100)
    self.batch_size = args.get('batch_size', 32)
    self.kernel_size = args.get('kernel_size', 25) ## FOR OPTIMIZING TREND COMPONENT SMOOTHNESS
    self.kernel_type = args.get('kernel_type', 'moving_avg')
    self.patience = args.get('patience', 3)
    self.learning_rate = args.get('learning_rate', 0.0001)
    self.des = args.get('des', 'test')
    self.loss = args.get('loss', 'mse')
    self.lradj = args.get('lradj', 'type3')
    self.use_amp = args.get('use_amp', False)
    #GPU
    self.use_gpu = args.get('use_gpu', True)
    self.gpu = args.get('gpu', 0)
    self.use_multi_gpu = args.get('use_multi_gpu', False)
    self.devices = args.get('devices', '0,1,2,3')
    self.test_flop = args.get('test_flop', False)
    #Augmentation
    self.aug_method = args.get('aug_method', 'NA')
    self.aug_rate = args.get('aug_rate', 0.5)
    self.in_batch_augmentation = args.get('in_batch_augmentation', False)
    self.in_dataset_augmentation = args.get('in_dataset_augmentation', False)
    self.data_size = args.get('data_size', 1)
    self.aug_data_size = args.get('aug_data_size', 1)
    self.seed = args.get('seed', 2021)
    #continue learning
    self.testset_div = args.get('testset_div', 2)
    self.test_time_train = args.get('test_time_train', False)
    #Formers
    self.embed = args.get('embed', 'timeF')
    self.enc_in = args.get('enc_in', 7)
    self.dec_in = args.get('dec_in', 7)
    self.c_out = args.get('c_out', 7)
    self.d_model = args.get('d_model', 512)
    self.n_heads = args.get('n_heads', 8)
    self.e_layers = args.get('e_layers', 2)
    self.d_layers = args.get('d_layers', 1)
    self.d_ff = args.get('d_ff', 2048)
    self.moving_avg = args.get('moving_avg', 25)
    self.factor = args.get('factor', 1)
    self.distil = args.get('distil', True)
    self.dropout = args.get('dropout', 0.1)
    self.activation = args.get('activation', 'relu')
    self.output_attention = args.get('output_attention', False)
    self.do_predict = args.get('do_predict', False)

    #Flinear
    self.train_mode = args.get('train_mode', 0)
    self.cut_freq = args.get('cut_freq', 0)
    self.base_T = args.get('base_T', 24)
    self.H_order = args.get('H_order', 2)

    self.use_gpu = True if torch.cuda.is_available() and self.use_gpu else False
    cfreq = args.get('cut_freq', 0)
    if cfreq == 0:
      self.cut_freq = int(self.seq_len // self.base_T + 1) * self.H_order + 10

    fix_seed = self.seed
    random.seed(fix_seed)
    torch.manual_seed(fix_seed)
    np.random.seed(fix_seed)

# %%
processed_data_dir_base = '/content/drive/MyDrive/M5-thesis/M5-FITS/processed/'
submissions_dir = '/content/drive/MyDrive/M5-thesis/submissions/partial/'
thesis_dir = '/content/drive/MyDrive/M5-thesis/'

os.chdir(thesis_dir)

# %%
global_df = pd.read_pickle(processed_data_dir_base + 'raw_data.pkl')

# %%
from torch.utils.data import DataLoader
from utils.timefeatures import time_features
from utils.augmentations import augmentation

start_date = pd.Timestamp("2011-01-29")
TRAIN_START = 0
TRAIN_END = 1941
TEST_END = 1969
TRAIN_LEN = TRAIN_END - TRAIN_START
HORIZON = 28

"""
get df_train and features
"""
def prepare_features(calendar):
  df = calendar.copy()
  df['snap_CA'] = df['snap_CA'].astype(int)
  df['snap_TX'] = df['snap_TX'].astype(int)
  df['snap_WI'] = df['snap_WI'].astype(int)
  df['snap_count'] = df[['snap_CA','snap_TX','snap_WI']].apply(np.sum,axis=1)

  df['is_event_1'] = [isinstance(x , str)*1 for x in df['event_name_1']]
  df['is_event_2'] = [isinstance(x , str)*1 for x in df['event_name_2']]
  df['is_event'] = df[['is_event_1', 'is_event_2']].apply(np.sum, axis=1)
  #turn into boolean
  # df['is_event'] = np.where(df['is_event']>0,1,0)

  df.drop(columns=['event_name_1', 'event_name_2', 'snap_CA', 'snap_TX', 'snap_WI', 'is_event_1', 'is_event_2'], inplace=True)
  df['date'] = start_date + pd.to_timedelta(df['d'] - 1, unit='D')

  return df

"""
get df_train and features
"""
def get_data_by_store_id(store_id, dept_id):
  temp = global_df.copy()

  store_data = temp[(temp['store_id'] == store_id) & (temp['dept_id'] == dept_id) & (temp['d'] >= TRAIN_START)]
  del temp
  gc.collect()

  return store_data

def aggregate_data(df):
  temp = df[['d', 'sales', 'date']]
  temp = temp.groupby(['d']).agg({
    'sales': 'sum',
    'date': 'first'
  }).reset_index()

  return temp


class Dataset_Custom(Dataset):
    def __init__(self, config, df, flag='train', size=None,
                 features='S',
                 target='OT', scale=True, timeenc=0, freq='h'):
        self.args = config
        # info
        if size == None:
            self.seq_len = 24 * 4 * 4
            self.label_len = 24 * 4
            self.pred_len = 24 * 4
        else:
            self.seq_len = size[0]
            self.label_len = size[1]
            self.pred_len = size[2]
        # init
        assert flag in ['train', 'test', 'val']
        type_map = {'train': 0, 'val': 1, 'test': 2}
        self.set_type = type_map[flag]

        self.features = features
        self.target = target
        self.scale = scale
        self.timeenc = timeenc
        self.freq = freq

        self.df_raw = df

        self.__read_data__()
        self.collect_all_data()
        if self.args.in_dataset_augmentation and self.set_type==0:
            self.data_augmentation()

    def __read_data__(self):
        self.scaler = StandardScaler()
        #TODO: read bottom-level data. Reproduce similar functionality as in DLinear

        '''
        df_raw.columns: ['date', ...(other features), target feature]
        '''
        cols = list(self.df_raw.columns)
        cols.remove(self.target)
        cols.remove('date')
        self.df_raw = self.df_raw[['date'] + cols + [self.target]]
        # print(cols)
        # num_train = int(len(df_raw) * 0.7)
        # num_test = int(len(df_raw) * 0.2)
        num_test = HORIZON  # Fixed to the last 28 days
        num_train = int((TRAIN_END - TRAIN_START) * self.args.train_data)
        num_vali = TRAIN_END - TRAIN_START - num_train
        border1s = [0, num_train - self.seq_len, len(self.df_raw) - num_test - self.seq_len]
        border2s = [num_train, num_train + num_vali, len(self.df_raw)]

        if self.args.test_time_train:
            num_train = int(len(self.df_raw) * 0.9)
            border1s = [0, num_train - self.seq_len, len(self.df_raw)]
            border2s = [num_train, len(self.df_raw), len(self.df_raw)]

        border1 = border1s[self.set_type]
        border2 = border2s[self.set_type]

        if self.features == 'M' or self.features == 'MS':
            cols_data = self.df_raw.columns[1:]
            df_data = self.df_raw[cols_data]
        elif self.features == 'S':
            df_data = self.df_raw[[self.target]]

        if self.scale:
            train_data = df_data[border1s[0]:border2s[0]]
            self.scaler.fit(train_data.values)
            # print(self.scaler.mean_)
            # exit()
            data = self.scaler.transform(df_data.values)
        else:
            data = df_data.values

        df_stamp = self.df_raw[['date']][border1:border2]
        df_stamp['date'] = pd.to_datetime(df_stamp.date)
        if self.timeenc == 0:
            df_stamp['month'] = df_stamp.date.apply(lambda row: row.month, 1)
            df_stamp['day'] = df_stamp.date.apply(lambda row: row.day, 1)
            df_stamp['weekday'] = df_stamp.date.apply(lambda row: row.weekday(), 1)
            df_stamp['hour'] = df_stamp.date.apply(lambda row: row.hour, 1)
            data_stamp = df_stamp.drop(['date'], 1).values
        elif self.timeenc == 1:
            data_stamp = time_features(pd.to_datetime(df_stamp['date'].values), freq=self.freq)
            data_stamp = data_stamp.transpose(1, 0)

        self.data_x = data[border1:border2]
        self.data_y = data[border1:border2]
        self.data_stamp = data_stamp
        print(border1, border2)

    def regenerate_augmentation_data(self):
        self.collect_all_data()
        self.data_augmentation()

    def reload_data(self, x_data, y_data, x_time, y_time):
        self.x_data = x_data
        self.y_data = y_data
        self.x_time = x_time
        self.y_time = y_time

    def collect_all_data(self):
        self.x_data = []
        self.y_data = []
        self.x_time = []
        self.y_time = []
        data_len = len(self.data_x) - self.seq_len - self.pred_len + 1
        mask_data_len = int((1-self.args.data_size) * data_len) if self.args.data_size < 1 else 0
        for i in range(len(self.data_x) - self.seq_len - self.pred_len + 1):
            if (self.set_type == 0 and i >= mask_data_len) or self.set_type != 0:
                s_begin = i
                s_end = s_begin + self.seq_len
                r_begin = s_end - self.label_len
                r_end = r_begin + self.label_len + self.pred_len
                self.x_data.append(self.data_x[s_begin:s_end])
                self.y_data.append(self.data_y[r_begin:r_end])
                self.x_time.append(self.data_stamp[s_begin:s_end])
                self.y_time.append(self.data_stamp[r_begin:r_end])

    def data_augmentation(self):
        origin_len = len(self.x_data)
        if not self.args.closer_data_aug_more:
            aug_size = [self.args.aug_data_size for i in range(origin_len)]
        else:
            aug_size = [int(self.args.aug_data_size * i/origin_len) + 1 for i in range(origin_len)]

        for i in range(origin_len):
            for _ in range(aug_size[i]):
                aug = augmentation('dataset')
                if self.args.aug_method == 'f_mask':
                    x,y = aug.freq_dropout(self.x_data[i],self.y_data[i],dropout_rate=self.args.aug_rate)
                elif self.args.aug_method == 'f_mix':
                    rand = float(np.random.random(1))
                    i2 = int(rand*len(self.x_data))
                    x,y = aug.freq_mix(self.x_data[i],self.y_data[i],self.x_data[i2],self.y_data[i2],dropout_rate=self.args.aug_rate)
                else:
                    raise ValueError
                self.x_data.append(x)
                self.y_data.append(y)
                self.x_time.append(self.x_time[i])
                self.y_time.append(self.y_time[i])

    def __getitem__(self, index):
        seq_x = self.x_data[index]
        seq_y = self.y_data[index]
        return seq_x, seq_y, self.x_time[index], self.y_time[index]

    def __len__(self):
        return len(self.x_data)

    def inverse_transform(self, data):
        return self.scaler.inverse_transform(data)

def data_provider(args, df, flag):
  timeenc = 0 if args.embed != 'timeF' else 1

  if flag == 'test':
      shuffle_flag = False
      drop_last = False # True
      batch_size = args.batch_size
      freq = args.freq
  else:
      shuffle_flag = True
      drop_last = True
      batch_size = args.batch_size
      freq = args.freq

  data_set = Dataset_Custom(
      config=args,
      flag=flag,
      df=df,
      size=[args.seq_len, args.label_len, args.pred_len],
      features=args.features,
      target=args.target,
      timeenc=timeenc,
      freq=freq,
      scale=args.scale
  )

  data_loader = DataLoader(
      data_set,
      batch_size=batch_size,
      shuffle=shuffle_flag,
      num_workers=args.num_workers,
      drop_last=drop_last)

  return data_set, data_loader

# %%
from re import X
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

class moving_avg(nn.Module):
    """
    Moving average block to highlight the trend of time series
    """
    def __init__(self, kernel_size, stride):
        super(moving_avg, self).__init__()
        self.kernel_size = kernel_size
        self.avg = nn.AvgPool1d(kernel_size=kernel_size, stride=stride, padding=0)

    def forward(self, x):
        # padding on the both ends of time series
        front = x[:, 0:1, :].repeat(1, (self.kernel_size - 1) // 2, 1)
        end = x[:, -1:, :].repeat(1, (self.kernel_size - 1) // 2, 1)
        x = torch.cat([front, x, end], dim=1)
        x = self.avg(x.permute(0, 2, 1))
        x = x.permute(0, 2, 1)
        return x

class MovingMedian(nn.Module):
    """
    Moving median block to highlight the trend of time series
    """

    def __init__(self, kernel_size, stride):
        super(MovingMedian, self).__init__()
        self.kernel_size = kernel_size
        self.stride = stride

    def forward(self, x):
        # Padding on both ends of the time series
        front = x[:, 0:1].repeat(1, (self.kernel_size - 1) // 2, 1)
        end = x[:, -1:].repeat(1, (self.kernel_size - 1) // 2, 1)
        x = torch.cat([front, x, end], dim=1)

        # Applying median filtering using unfold to extract sliding windows
        unfolded = x.unfold(dimension=1, size=self.kernel_size, step=self.stride)  # Shape: (batch, windows, kernel_size)
        median_filtered = unfolded.median(dim=-1).values  # Take the median along the last dimension

        return median_filtered

class series_decomp(nn.Module):
    """
    Series decomposition block
    """
    def __init__(self, configs):
        super(series_decomp, self).__init__()
        if configs.kernel_type == 'moving_avg':
          self.moving_avg = moving_avg(configs.kernel_size, stride=1)
        else:
          self.moving_avg = MovingMedian(configs.kernel_size, stride=1)

    def forward(self, x):
        moving_mean = self.moving_avg(x)
        res = x - moving_mean
        return res, moving_mean

class Model(nn.Module):
    """
    DLinear
    """
    def __init__(self, configs):
        super(Model, self).__init__()
        self.seq_len = configs.seq_len
        self.pred_len = configs.pred_len

        # Decompsition Kernel Size
        kernel_size = configs.kernel_size
        print(f"kernel size:")
        self.decompsition = series_decomp(configs)
        self.individual = configs.individual
        self.channels = configs.enc_in

        if self.individual:
            self.Linear_Seasonal = nn.ModuleList()
            self.Linear_Trend = nn.ModuleList()
            self.Linear_Decoder = nn.ModuleList()
            for i in range(self.channels):
                self.Linear_Seasonal.append(nn.Linear(self.seq_len,self.pred_len))
                self.Linear_Seasonal[i].weight = nn.Parameter((1/self.seq_len)*torch.ones([self.pred_len,self.seq_len]))
                self.Linear_Trend.append(nn.Linear(self.seq_len,self.pred_len))
                self.Linear_Trend[i].weight = nn.Parameter((1/self.seq_len)*torch.ones([self.pred_len,self.seq_len]))
                self.Linear_Decoder.append(nn.Linear(self.seq_len,self.pred_len))
        else:
            self.Linear_Seasonal = nn.Linear(self.seq_len,self.pred_len)
            self.Linear_Trend = nn.Linear(self.seq_len,self.pred_len)
            self.Linear_Decoder = nn.Linear(self.seq_len,self.pred_len)
            self.Linear_Seasonal.weight = nn.Parameter((1/self.seq_len)*torch.ones([self.pred_len,self.seq_len]))
            self.Linear_Trend.weight = nn.Parameter((1/self.seq_len)*torch.ones([self.pred_len,self.seq_len]))

    def forward(self, x):
        # x: [Batch, Input length, Channel]
        seasonal_init, trend_init = self.decompsition(x)
        seasonal_init, trend_init = seasonal_init.permute(0,2,1), trend_init.permute(0,2,1)
        if self.individual:
            seasonal_output = torch.zeros([seasonal_init.size(0),seasonal_init.size(1),self.pred_len],dtype=seasonal_init.dtype).to(seasonal_init.device)
            trend_output = torch.zeros([trend_init.size(0),trend_init.size(1),self.pred_len],dtype=trend_init.dtype).to(trend_init.device)
            for i in range(self.channels):
                seasonal_output[:,i,:] = self.Linear_Seasonal[i](seasonal_init[:,i,:])
                trend_output[:,i,:] = self.Linear_Trend[i](trend_init[:,i,:])
        else:
            seasonal_output = self.Linear_Seasonal(seasonal_init)
            trend_output = self.Linear_Trend(trend_init)

        x = seasonal_output + trend_output
        return x.permute(0,2,1) # to [Batch, Output length, Channel]

# %%
from utils.tools import EarlyStopping, adjust_learning_rate, test_params_flop, visual
from utils.metrics import metric
import numpy as np
import torch
import torch.nn as nn
from torch import optim
from utils.augmentations import augmentation
import os
import time

import warnings
import matplotlib.pyplot as plt
import numpy as np

from thop import profile

class RMSELoss(nn.Module):
    def __init__(self):
        super().__init__()
        self.mse = nn.MSELoss()

    def forward(self,yhat,y):
        return torch.sqrt(self.mse(yhat,y))

class DLinear(object):
    def __init__(self, args, setting, df_train):
        self.args = args
        self.device = self._acquire_device()
        self.model = self._build_model().to(self.device)
        self.df_train = df_train
        self.top_level = self.get_top_level()
        self.setting = setting

    def get_top_level(self):
      """
      Calculate top level time series by aggregating low level time-series
      """
      data = aggregate_data(self.df_train)

      return data

    def get_weights(self):
      temp = self.df_train.pivot(index='id', columns='d', values='sales')
      temp.fillna(0, inplace=True)
      w = np.sum(temp.iloc[:, -56:-28].values, axis=1) / sum(self.top_level['sales'].iloc[-56:-28])
      w = w.reshape(len(w), 1)

      del temp
      gc.collect()

      return w

    def _build_model(self):
        raise NotImplementedError
        return None

    def _acquire_device(self):
        if self.args.use_gpu:
            os.environ["CUDA_VISIBLE_DEVICES"] = str(
                self.args.gpu) if not self.args.use_multi_gpu else self.args.devices
            device = torch.device('cuda:{}'.format(self.args.gpu))
            print('Use GPU: cuda:{}'.format(self.args.gpu))
        else:
            device = torch.device('cpu')
            print('Use CPU')
        return device

    def _get_data(self):
        pass

    def vali(self):
        pass

    def train(self):
        pass

    def test(self):
        pass

class M5DLinear(DLinear):
    def __init__(self, args, setting, df_train):
        super(M5DLinear, self).__init__(args, setting, df_train)

    def _build_model(self):
        model = Model(self.args).float()

        if self.args.use_multi_gpu and self.args.use_gpu:
            model = nn.DataParallel(model, device_ids=self.args.device_ids)

        return model

    def _get_data(self, flag):
        data_set, data_loader = data_provider(self.args, self.get_top_level(), flag)

        return data_set, data_loader

    def _select_optimizer(self):
        model_optim = optim.Adam(self.model.parameters(), lr=self.args.learning_rate)
        print('!!!!!!!!!!!!!!learning rate!!!!!!!!!!!!!!!')
        print(self.args.learning_rate)
        return model_optim

    def _select_criterion(self):
        criterion = nn.MSELoss()
        return criterion

    def _get_profile(self, model):
        _input=torch.randn(self.args.batch_size, self.args.seq_len, self.args.enc_in).to(self.device)
        macs, params = profile(model, inputs=(_input,))
        print('FLOPs: ', macs)
        print('params: ', params)
        return macs, params

    def vali(self, vali_data, vali_loader, criterion):
        total_loss = []
        self.model.eval()
        with torch.no_grad():
            for i, (batch_x, batch_y, batch_x_mark, batch_y_mark) in enumerate(vali_loader):
                batch_x = batch_x.float().to(self.device)
                batch_y = batch_y.float().to(self.device)[:,-self.args.pred_len:,:]
                batch_xy = torch.cat([batch_x, batch_y], dim=1)

                batch_x_mark = batch_x_mark.float().to(self.device)
                batch_y_mark = batch_y_mark.float().to(self.device)

                # decoder input
                dec_inp = torch.zeros_like(batch_y[:, -self.args.pred_len:, :]).float()
                dec_inp = torch.cat([batch_y[:, :self.args.label_len, :], dec_inp], dim=1).float().to(self.device)
                # encoder - decoder
                outputs = self.model(batch_x)
                f_dim = -1 if self.args.features == 'MS' else 0
                outputs = outputs[:, -self.args.pred_len:, f_dim:]
                batch_y = batch_y[:, -self.args.pred_len:, f_dim:]

                pred = outputs.detach().cpu()
                true = batch_y.detach().cpu()

                loss = criterion(pred, true)

                total_loss.append(loss)
        total_loss = np.average(total_loss)
        self.model.train()
        return total_loss

    def train(self, ft=False):
        train_data, train_loader = self._get_data(flag='train')
        vali_data, vali_loader = self._get_data(flag='val')
        test_data, test_loader = self._get_data(flag='test')
        print(self.model)
        self._get_profile(self.model)
        print('Trainable parameters: ', sum(p.numel() for p in self.model.parameters() if p.requires_grad))

        path = os.path.join(self.args.checkpoints, self.setting)
        if not os.path.exists(path):
            os.makedirs(path)

        time_now = time.time()

        train_steps = len(train_loader)
        early_stopping = EarlyStopping(patience=self.args.patience, verbose=True)

        model_optim = self._select_optimizer()
        criterion = self._select_criterion()

        epoch_times = []
        for epoch in range(self.args.train_epochs):
            iter_count = 0
            train_loss = []

            self.model.train()
            epoch_time = time.time()
            if self.args.in_dataset_augmentation:
                train_loader.dataset.regenerate_augmentation_data()

            for i, (batch_x, batch_y, batch_x_mark, batch_y_mark) in enumerate(train_loader):
                iter_count += 1
                model_optim.zero_grad()

                batch_x = batch_x.float().to(self.device)
                batch_y = batch_y.float().to(self.device)[:,-self.args.pred_len:,:]
                batch_x_mark = batch_x_mark.float().to(self.device)
                batch_y_mark = batch_y_mark.float().to(self.device)
                batch_xy = torch.cat([batch_x, batch_y], dim=1)

                # decoder input
                dec_inp = torch.zeros_like(batch_y[:, -self.args.pred_len:, :]).float()
                dec_inp = torch.cat([batch_y[:, :self.args.label_len, :], dec_inp], dim=1).float().to(self.device)

                # encoder - decoder
                outputs = self.model(batch_x)

                # print(outputs.shape,batch_y.shape)
                f_dim = -1 if self.args.features == 'MS' else 0
                outputs = outputs[:, -self.args.pred_len:, f_dim:]
                batch_y = batch_y[:, -self.args.pred_len:, f_dim:].to(self.device)
                # print(outputs.shape,batch_xy.shape)
                #loss = criterion(outputs, batch_xy)
                loss = criterion(outputs, batch_y)
                train_loss.append(loss.item())

                if (i + 1) % 100 == 0:
                    print("\titers: {0}, epoch: {1} | loss: {2:.7f}".format(i + 1, epoch + 1, loss.item()))
                    speed = (time.time() - time_now) / iter_count
                    left_time = speed * ((self.args.train_epochs - epoch) * train_steps - i)
                    print('\tspeed: {:.4f}s/iter; left time: {:.4f}s'.format(speed, left_time))
                    iter_count = 0
                    time_now = time.time()

                loss.backward()
                model_optim.step()

            dur = time.time() - epoch_time
            epoch_times.append(dur)
            print("Epoch: {} cost time: {}".format(epoch + 1, dur))
            train_loss = np.average(train_loss)
            vali_loss = self.vali(vali_data, vali_loader, criterion)
            test_loss = self.vali(test_data, test_loader, criterion)

            print("Epoch: {0}, Steps: {1} | Train Loss: {2:.7f} Vali Loss: {3:.7f} Test Loss: {4:.7f}".format(
                epoch + 1, train_steps, train_loss, vali_loss, test_loss))
            early_stopping(vali_loss, self.model, path)
            if early_stopping.early_stop:
                print("Early stopping")
                break

            adjust_learning_rate(model_optim, epoch + 1, self.args)

        best_model_path = path + '/' + 'checkpoint.pth'
        torch.save(self.model.state_dict(), best_model_path)
        self.model.load_state_dict(torch.load(best_model_path, weights_only=True))

        return self.model, epoch_times

    def load_saved_model(self):
      print('loading model')
      path = os.path.join(self.args.checkpoints, self.setting)
      path += '/' + 'checkpoint.pth'
      state_dict = torch.load(path, weights_only=True)
      # del state_dict['total_ops']
      # del state_dict['total_params']

      self.model.load_state_dict(state_dict)

    def predict_top_level(self, test=0):
      pred_set, pred_loader = self._get_data(flag='test')

      if test:
        self.load_saved_model()

      preds = []

      self.model.eval()
      with torch.no_grad():
        for i, (batch_x, batch_y, batch_x_mark, batch_y_mark) in enumerate(pred_loader):
          batch_x = batch_x.float().to(self.device)
          batch_y = batch_y.float()
          batch_x_mark = batch_x_mark.float().to(self.device)
          batch_y_mark = batch_y_mark.float().to(self.device)

          # decoder input
          dec_inp = torch.zeros([batch_y.shape[0], self.args.pred_len, batch_y.shape[2]]).float().to(batch_y.device)
          dec_inp = torch.cat([batch_y[:, :self.args.label_len, :], dec_inp], dim=1).float().to(self.device)
          # encoder - decoder
          outputs = self.model(batch_x)
          f_dim = -1 if self.args.features == 'MS' else 0
          outputs_ = outputs[:, -self.args.pred_len:, f_dim:]
          pred = outputs_.detach().cpu().numpy()  # .squeeze()
          preds.append(pred)

        preds = np.array(preds)
        preds = preds.reshape(-1, preds.shape[-2], preds.shape[-1])
        preds = pred_set.inverse_transform(preds[0])

      return preds.flatten()

    def predict_bottom_level(self, test=0):
      w = self.get_weights()
      top_level_preds = self.predict_top_level(test=test)
      top_level_preds = top_level_preds.reshape(1,len(top_level_preds))
      preds = np.multiply(top_level_preds, w)

      item_ids = self.df_train['id'].unique()
      res = pd.DataFrame({
          'id': item_ids
      })

      predictions_df = pd.DataFrame(preds, columns=[f'F{i+1}' for i in range(28)])
      preds = pd.concat([res['id'], predictions_df], axis=1)

      preds.set_index('id', inplace=True)

      return preds

# %%
def get_model_name(config, dept_id, store_id):
  setting = '{}_{}_{}_ft{}_sl{}_ll{}_pl{}_H{}_{}_{}_{}'.format(
            config.model_id,
            config.model,
            config.data,
            config.features,
            config.seq_len,
            config.label_len,
            config.pred_len,
            config.H_order,
            dept_id,
            store_id, 1)

  return setting

# %%
args = {
    'model_id': 'dlinear-median-1.0',
    'data': 'custom',
    'features': 'S',
    'model': 'DLinear',
    'checkpoints': '/content/drive/MyDrive/M5-thesis/M5-DLinear/checkpoints/v2',
    'seq_len': 56,
    'batch_size': 24,
    'seed': 42,
    'learning_rate': 0.005,
    'train_data': 0.8,
    'kernel_size': 21
}

config = Config(args)

# %%
store_id = 'WI_2'
dept_id = 'FOODS_2'

# %%
setting = get_model_name(config, dept_id, store_id)
data = get_data_by_store_id(store_id, dept_id)

# %%
dlinear = M5DLinear(config, setting=setting, df_train=data)
model = dlinear.train()

# %%
stores = global_df['store_id'].unique()
depts = global_df['dept_id'].unique()
model_training_time_path = '/content/drive/MyDrive/M5-thesis/M5-DLinear/training_times/'

# %%
def train_model(model_name, args):
  print(f"training {model_name}")
  submission = pd.read_csv('/content/drive/MyDrive/data/m5-data/sample_submission.csv')
  submission.set_index('id', inplace=True)
  config = Config(args)

  full_training_time = 0
  cat_training_times = []
  for store_id in stores:
    for dept_id in depts:
      print(f"training {store_id} + {dept_id}")
      setting = '{}_{}_{}_ft{}_sl{}_ll{}_pl{}_H{}_{}_{}_{}'.format(
            config.model_id,
            config.model,
            config.data,
            config.features,
            config.seq_len,
            config.label_len,
            config.pred_len,
            config.H_order,
            dept_id,
            store_id, 1)

      df_train = get_data_by_store_id(store_id, dept_id)
      model = M5DLinear(config, setting=setting, df_train=df_train)
      _, train_times = model.train()
      train_times = sum(train_times)
      cat_training_times.append({'cat': f"{store_id}_{dept_id}", 'duration': train_times})
      full_training_time += train_times
      sub_submission = model.predict_bottom_level()

      submission.update(sub_submission)

      # sub_submission.reset_index(inplace=True)
      # sub_submission.to_csv(f"{submission_parts_dir}{model_name}_{store_id}_{dept_id}.csv", index=False)
      print(f"{model_name} trained for {train_times}")

      del df_train
      del model
      gc.collect()

  submission.reset_index(inplace=True)
  submission.to_csv(f"{submissions_dir}{model_name}.csv", index=False)
  train_times = pd.DataFrame(cat_training_times, columns=['cat', 'duration'])
  train_times.to_csv(f"{model_training_time_path}{model_name}_training_times.csv", index=False)

  return submission, full_training_time

# %%
models = [
  # {
  #     'model_id': 'dlinear-median-1.0',
  #     'data': 'custom',
  #     'features': 'S',
  #     'model': 'DLinear',
  #     'checkpoints': '/content/drive/MyDrive/M5-thesis/M5-DLinear/checkpoints/',
  #     'seq_len': 56,
  #     'batch_size': 24,
  #     'seed': 42,
  #     'learning_rate': 0.005,
  #     'train_data': 0.8,
  #     'kernel_size': 21,
  #     'kernel_type': 'moving_median'
  # },
#   {
#     'model_id': 'dlinear-moving-avg-1.0',
#     'data': 'custom',
#     'features': 'S',
#     'model': 'DLinear',
#     'checkpoints': '/content/drive/MyDrive/M5-thesis/M5-DLinear/checkpoints/',
#     'seq_len': 56,
#     'batch_size': 24,
#     'seed': 42,
#     'learning_rate': 0.005,
#     'train_data': 0.8,
#     'kernel_size': 21
# },
#     {
#     'model_id': 'dlinear-media-lb-84-1.0',
#     'data': 'custom',
#     'features': 'S',
#     'model': 'DLinear',
#     'checkpoints': '/content/drive/MyDrive/M5-thesis/M5-DLinear/checkpoints/',
#     'seq_len': 84,
#     'batch_size': 24,
#     'seed': 42,
#     'learning_rate': 0.005,
#     'train_data': 0.8,
#     'kernel_size': 21,
#     'kernel_type': 'moving_median',
# },
#       {
#     'model_id': 'dlinear-media-lb-84-0.7-1.0',
#     'data': 'custom',
#     'features': 'S',
#     'model': 'DLinear',
#     'checkpoints': '/content/drive/MyDrive/M5-thesis/M5-DLinear/checkpoints/',
#     'seq_len': 84,
#     'batch_size': 24,
#     'seed': 42,
#     'learning_rate': 0.005,
#     'train_data': 0.7,
#     'kernel_size': 21,
#     'kernel_type': 'moving_median',
# },
#         {
#     'model_id': 'dlinear-media-lb-70-1.0',
#     'data': 'custom',
#     'features': 'S',
#     'model': 'DLinear',
#     'checkpoints': '/content/drive/MyDrive/M5-thesis/M5-DLinear/checkpoints/',
#     'seq_len': 84,
#     'batch_size': 24,
#     'seed': 42,
#     'learning_rate': 0.005,
#     'train_data': 0.8,
#     'kernel_size': 21,
#     'kernel_type': 'moving_median',
# },
#           {
#     'model_id': 'dlinear-media-lb-70-0.7-1.0',
#     'data': 'custom',
#     'features': 'S',
#     'model': 'DLinear',
#     'checkpoints': '/content/drive/MyDrive/M5-thesis/M5-DLinear/checkpoints/',
#     'seq_len': 84,
#     'batch_size': 24,
#     'seed': 42,
#     'learning_rate': 0.005,
#     'train_data': 0.7,
#     'kernel_size': 21,
#     'kernel_type': 'moving_median',
# },
            {
    'model_id': 'dlinear-media-lb-112-0.7-1.0',
    'data': 'custom',
    'features': 'S',
    'model': 'DLinear',
    'checkpoints': '/content/drive/MyDrive/M5-thesis/M5-DLinear/checkpoints/',
    'seq_len': 112,
    'batch_size': 24,
    'seed': 42,
    'learning_rate': 0.005,
    'train_data': 0.7,
    'kernel_size': 21,
    'kernel_type': 'moving_median',
},
              {
    'model_id': 'dlinear-media-lb-112-0.85-1.0',
    'data': 'custom',
    'features': 'S',
    'model': 'DLinear',
    'checkpoints': '/content/drive/MyDrive/M5-thesis/M5-DLinear/checkpoints/',
    'seq_len': 112,
    'batch_size': 24,
    'seed': 42,
    'learning_rate': 0.005,
    'train_data': 0.85,
    'kernel_size': 21,
    'kernel_type': 'moving_median',
}
]

# %%
model_training_times = []
cat_times = []
for model in models:
  sub, durations = train_model(model['model_id'], model)
  model_training_times.append({'name': model['model_id'], 'duration': durations})
# Out:
# Streaming output truncated to the last 5000 lines.
# 0 1358
# 1246 1941
# 1829 1969
# Model(
#   (decompsition): series_decomp(
#     (moving_avg): MovingMedian()
#   )
#   (Linear_Seasonal): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Trend): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Decoder): Linear(in_features=112, out_features=28, bias=True)
# )
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# FLOPs:  1053696.0
# params:  6328.0
# Trainable parameters:  9492
# !!!!!!!!!!!!!!learning rate!!!!!!!!!!!!!!!
# 0.005
# Epoch: 1 cost time: 1.6267499923706055
# Epoch: 1, Steps: 50 | Train Loss: 0.9391995 Vali Loss: 3.3450122 Test Loss: 17.2746773
# Validation loss decreased (inf --> 3.345012).  Saving model ...
# Updating learning rate to 0.005
# Epoch: 2 cost time: 1.4875688552856445
# Epoch: 2, Steps: 50 | Train Loss: 0.8676937 Vali Loss: 3.2757263 Test Loss: 17.2238350
# Validation loss decreased (3.345012 --> 3.275726).  Saving model ...
# Updating learning rate to 0.00475
# Epoch: 3 cost time: 1.5129311084747314
# Epoch: 3, Steps: 50 | Train Loss: 0.8531725 Vali Loss: 3.3684013 Test Loss: 16.0601978
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.0045125
# Epoch: 4 cost time: 1.62103271484375
# Epoch: 4, Steps: 50 | Train Loss: 0.8389397 Vali Loss: 3.0820177 Test Loss: 16.8832932
# Validation loss decreased (3.275726 --> 3.082018).  Saving model ...
# Updating learning rate to 0.004286875
# Epoch: 5 cost time: 1.576451301574707
# Epoch: 5, Steps: 50 | Train Loss: 0.8324874 Vali Loss: 3.0564911 Test Loss: 16.7002506
# Validation loss decreased (3.082018 --> 3.056491).  Saving model ...
# Updating learning rate to 0.00407253125
# Epoch: 6 cost time: 1.565680742263794
# Epoch: 6, Steps: 50 | Train Loss: 0.8234607 Vali Loss: 2.8784542 Test Loss: 18.6795712
# Validation loss decreased (3.056491 --> 2.878454).  Saving model ...
# Updating learning rate to 0.003868904687499999
# Epoch: 7 cost time: 1.5861382484436035
# Epoch: 7, Steps: 50 | Train Loss: 0.8152507 Vali Loss: 2.8798311 Test Loss: 20.2938271
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.003675459453124999
# Epoch: 8 cost time: 1.559053659439087
# Epoch: 8, Steps: 50 | Train Loss: 0.8170134 Vali Loss: 3.2341866 Test Loss: 15.2998285
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 0.003491686480468749
# Epoch: 9 cost time: 1.5355937480926514
# Epoch: 9, Steps: 50 | Train Loss: 0.8091507 Vali Loss: 3.1024737 Test Loss: 17.6452312
# EarlyStopping counter: 3 out of 3
# Early stopping
# 1829 1969
# dlinear-media-lb-112-0.7-1.0 trained for 14.071200370788574
# training TX_1 + HOUSEHOLD_1
# Use GPU: cuda:0
# kernel size:
# 0 1358
# 1246 1941
# 1829 1969
# Model(
#   (decompsition): series_decomp(
#     (moving_avg): MovingMedian()
#   )
#   (Linear_Seasonal): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Trend): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Decoder): Linear(in_features=112, out_features=28, bias=True)
# )
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# FLOPs:  1053696.0
# params:  6328.0
# Trainable parameters:  9492
# !!!!!!!!!!!!!!learning rate!!!!!!!!!!!!!!!
# 0.005
# Epoch: 1 cost time: 1.5357227325439453
# Epoch: 1, Steps: 50 | Train Loss: 0.2916511 Vali Loss: 0.2879995 Test Loss: 16.1820316
# Validation loss decreased (inf --> 0.287999).  Saving model ...
# Updating learning rate to 0.005
# Epoch: 2 cost time: 1.4733726978302002
# Epoch: 2, Steps: 50 | Train Loss: 0.2216542 Vali Loss: 0.2908792 Test Loss: 17.1747932
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.00475
# Epoch: 3 cost time: 1.6420719623565674
# Epoch: 3, Steps: 50 | Train Loss: 0.2127911 Vali Loss: 0.2902310 Test Loss: 17.7679024
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 0.0045125
# Epoch: 4 cost time: 1.5208263397216797
# Epoch: 4, Steps: 50 | Train Loss: 0.2075570 Vali Loss: 0.3024018 Test Loss: 18.2866020
# EarlyStopping counter: 3 out of 3
# Early stopping
# 1829 1969
# dlinear-media-lb-112-0.7-1.0 trained for 6.171993732452393
# training TX_1 + HOUSEHOLD_2
# Use GPU: cuda:0
# kernel size:
# 0 1358
# 1246 1941
# 1829 1969
# Model(
#   (decompsition): series_decomp(
#     (moving_avg): MovingMedian()
#   )
#   (Linear_Seasonal): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Trend): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Decoder): Linear(in_features=112, out_features=28, bias=True)
# )
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# FLOPs:  1053696.0
# params:  6328.0
# Trainable parameters:  9492
# !!!!!!!!!!!!!!learning rate!!!!!!!!!!!!!!!
# 0.005
# Epoch: 1 cost time: 1.6737895011901855
# Epoch: 1, Steps: 50 | Train Loss: 0.6332235 Vali Loss: 0.7477264 Test Loss: 31.3246765
# Validation loss decreased (inf --> 0.747726).  Saving model ...
# Updating learning rate to 0.005
# Epoch: 2 cost time: 1.538663387298584
# Epoch: 2, Steps: 50 | Train Loss: 0.5925900 Vali Loss: 0.7273515 Test Loss: 34.7618828
# Validation loss decreased (0.747726 --> 0.727351).  Saving model ...
# Updating learning rate to 0.00475
# Epoch: 3 cost time: 1.4653570652008057
# Epoch: 3, Steps: 50 | Train Loss: 0.5708242 Vali Loss: 0.7048609 Test Loss: 32.1106224
# Validation loss decreased (0.727351 --> 0.704861).  Saving model ...
# Updating learning rate to 0.0045125
# Epoch: 4 cost time: 1.6673176288604736
# Epoch: 4, Steps: 50 | Train Loss: 0.5671867 Vali Loss: 0.7207390 Test Loss: 35.7164803
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.004286875
# Epoch: 5 cost time: 1.5444834232330322
# Epoch: 5, Steps: 50 | Train Loss: 0.5628487 Vali Loss: 0.7469020 Test Loss: 31.6794872
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 0.00407253125
# Epoch: 6 cost time: 1.5148327350616455
# Epoch: 6, Steps: 50 | Train Loss: 0.5691455 Vali Loss: 0.7066225 Test Loss: 34.0941086
# EarlyStopping counter: 3 out of 3
# Early stopping
# 1829 1969
# dlinear-media-lb-112-0.7-1.0 trained for 9.404443740844727
# training TX_1 + FOODS_1
# Use GPU: cuda:0
# kernel size:
# 0 1358
# 1246 1941
# 1829 1969
# Model(
#   (decompsition): series_decomp(
#     (moving_avg): MovingMedian()
#   )
#   (Linear_Seasonal): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Trend): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Decoder): Linear(in_features=112, out_features=28, bias=True)
# )
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# FLOPs:  1053696.0
# params:  6328.0
# Trainable parameters:  9492
# !!!!!!!!!!!!!!learning rate!!!!!!!!!!!!!!!
# 0.005
# Epoch: 1 cost time: 1.5199062824249268
# Epoch: 1, Steps: 50 | Train Loss: 0.5775790 Vali Loss: 0.8448073 Test Loss: 15.7962847
# Validation loss decreased (inf --> 0.844807).  Saving model ...
# Updating learning rate to 0.005
# Epoch: 2 cost time: 1.553189992904663
# Epoch: 2, Steps: 50 | Train Loss: 0.5235560 Vali Loss: 0.8573530 Test Loss: 15.5254965
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.00475
# Epoch: 3 cost time: 1.6251230239868164
# Epoch: 3, Steps: 50 | Train Loss: 0.5128961 Vali Loss: 0.8647928 Test Loss: 16.8559151
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 0.0045125
# Epoch: 4 cost time: 1.513974666595459
# Epoch: 4, Steps: 50 | Train Loss: 0.5088246 Vali Loss: 0.8956680 Test Loss: 16.3782177
# EarlyStopping counter: 3 out of 3
# Early stopping
# 1829 1969
# dlinear-media-lb-112-0.7-1.0 trained for 6.212193965911865
# training TX_1 + FOODS_2
# Use GPU: cuda:0
# kernel size:
# 0 1358
# 1246 1941
# 1829 1969
# Model(
#   (decompsition): series_decomp(
#     (moving_avg): MovingMedian()
#   )
#   (Linear_Seasonal): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Trend): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Decoder): Linear(in_features=112, out_features=28, bias=True)
# )
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# FLOPs:  1053696.0
# params:  6328.0
# Trainable parameters:  9492
# !!!!!!!!!!!!!!learning rate!!!!!!!!!!!!!!!
# 0.005
# Epoch: 1 cost time: 1.6221816539764404
# Epoch: 1, Steps: 50 | Train Loss: 0.4885706 Vali Loss: 0.4395375 Test Loss: 17.8606548
# Validation loss decreased (inf --> 0.439537).  Saving model ...
# Updating learning rate to 0.005
# Epoch: 2 cost time: 1.5469841957092285
# Epoch: 2, Steps: 50 | Train Loss: 0.4062568 Vali Loss: 0.4415396 Test Loss: 18.2320194
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.00475
# Epoch: 3 cost time: 1.454993486404419
# Epoch: 3, Steps: 50 | Train Loss: 0.3983014 Vali Loss: 0.4433288 Test Loss: 17.6822853
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 0.0045125
# Epoch: 4 cost time: 1.6116740703582764
# Epoch: 4, Steps: 50 | Train Loss: 0.3942060 Vali Loss: 0.4483249 Test Loss: 18.0467129
# EarlyStopping counter: 3 out of 3
# Early stopping
# 1829 1969
# dlinear-media-lb-112-0.7-1.0 trained for 6.235833406448364
# training TX_1 + FOODS_3
# Use GPU: cuda:0
# kernel size:
# 0 1358
# 1246 1941
# 1829 1969
# Model(
#   (decompsition): series_decomp(
#     (moving_avg): MovingMedian()
#   )
#   (Linear_Seasonal): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Trend): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Decoder): Linear(in_features=112, out_features=28, bias=True)
# )
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# FLOPs:  1053696.0
# params:  6328.0
# Trainable parameters:  9492
# !!!!!!!!!!!!!!learning rate!!!!!!!!!!!!!!!
# 0.005
# Epoch: 1 cost time: 1.5852179527282715
# Epoch: 1, Steps: 50 | Train Loss: 0.4900112 Vali Loss: 0.3935218 Test Loss: 21.1998653
# Validation loss decreased (inf --> 0.393522).  Saving model ...
# Updating learning rate to 0.005
# Epoch: 2 cost time: 1.6395504474639893
# Epoch: 2, Steps: 50 | Train Loss: 0.4117268 Vali Loss: 0.3963014 Test Loss: 23.6887474
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.00475
# Epoch: 3 cost time: 1.5400416851043701
# Epoch: 3, Steps: 50 | Train Loss: 0.4036414 Vali Loss: 0.3840175 Test Loss: 22.4438934
# Validation loss decreased (0.393522 --> 0.384017).  Saving model ...
# Updating learning rate to 0.0045125
# Epoch: 4 cost time: 1.5686979293823242
# Epoch: 4, Steps: 50 | Train Loss: 0.4011026 Vali Loss: 0.3888094 Test Loss: 22.1281071
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.004286875
# Epoch: 5 cost time: 1.660346269607544
# Epoch: 5, Steps: 50 | Train Loss: 0.3947957 Vali Loss: 0.3943490 Test Loss: 23.0818062
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 0.00407253125
# Epoch: 6 cost time: 1.5384421348571777
# Epoch: 6, Steps: 50 | Train Loss: 0.3953271 Vali Loss: 0.3905691 Test Loss: 21.9680996
# EarlyStopping counter: 3 out of 3
# Early stopping
# 1829 1969
# dlinear-media-lb-112-0.7-1.0 trained for 9.532296419143677
# training TX_2 + HOBBIES_1
# Use GPU: cuda:0
# kernel size:
# 0 1358
# 1246 1941
# 1829 1969
# Model(
#   (decompsition): series_decomp(
#     (moving_avg): MovingMedian()
#   )
#   (Linear_Seasonal): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Trend): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Decoder): Linear(in_features=112, out_features=28, bias=True)
# )
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# FLOPs:  1053696.0
# params:  6328.0
# Trainable parameters:  9492
# !!!!!!!!!!!!!!learning rate!!!!!!!!!!!!!!!
# 0.005
# Epoch: 1 cost time: 1.6701934337615967
# Epoch: 1, Steps: 50 | Train Loss: 0.5561098 Vali Loss: 0.5102981 Test Loss: 19.8269978
# Validation loss decreased (inf --> 0.510298).  Saving model ...
# Updating learning rate to 0.005
# Epoch: 2 cost time: 1.5541083812713623
# Epoch: 2, Steps: 50 | Train Loss: 0.4894384 Vali Loss: 0.5349016 Test Loss: 19.9812412
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.00475
# Epoch: 3 cost time: 1.548304796218872
# Epoch: 3, Steps: 50 | Train Loss: 0.4750116 Vali Loss: 0.5358621 Test Loss: 20.6570759
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 0.0045125
# Epoch: 4 cost time: 1.628218412399292
# Epoch: 4, Steps: 50 | Train Loss: 0.4697343 Vali Loss: 0.5324069 Test Loss: 20.8683796
# EarlyStopping counter: 3 out of 3
# Early stopping
# 1829 1969
# dlinear-media-lb-112-0.7-1.0 trained for 6.400825023651123
# training TX_2 + HOBBIES_2
# Use GPU: cuda:0
# kernel size:
# 0 1358
# 1246 1941
# 1829 1969
# Model(
#   (decompsition): series_decomp(
#     (moving_avg): MovingMedian()
#   )
#   (Linear_Seasonal): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Trend): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Decoder): Linear(in_features=112, out_features=28, bias=True)
# )
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# FLOPs:  1053696.0
# params:  6328.0
# Trainable parameters:  9492
# !!!!!!!!!!!!!!learning rate!!!!!!!!!!!!!!!
# 0.005
# Epoch: 1 cost time: 1.5063326358795166
# Epoch: 1, Steps: 50 | Train Loss: 1.0317972 Vali Loss: 1.9704466 Test Loss: 6.3272977
# Validation loss decreased (inf --> 1.970447).  Saving model ...
# Updating learning rate to 0.005
# Epoch: 2 cost time: 1.6714203357696533
# Epoch: 2, Steps: 50 | Train Loss: 0.9517950 Vali Loss: 2.0076437 Test Loss: 6.5896783
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.00475
# Epoch: 3 cost time: 1.5840978622436523
# Epoch: 3, Steps: 50 | Train Loss: 0.9444255 Vali Loss: 1.9025177 Test Loss: 6.2208085
# Validation loss decreased (1.970447 --> 1.902518).  Saving model ...
# Updating learning rate to 0.0045125
# Epoch: 4 cost time: 1.5245404243469238
# Epoch: 4, Steps: 50 | Train Loss: 0.9311323 Vali Loss: 1.9179640 Test Loss: 6.5370874
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.004286875
# Epoch: 5 cost time: 1.5399532318115234
# Epoch: 5, Steps: 50 | Train Loss: 0.9309382 Vali Loss: 1.7073079 Test Loss: 7.7623343
# Validation loss decreased (1.902518 --> 1.707308).  Saving model ...
# Updating learning rate to 0.00407253125
# Epoch: 6 cost time: 1.5510504245758057
# Epoch: 6, Steps: 50 | Train Loss: 0.9216507 Vali Loss: 1.7815170 Test Loss: 7.8646903
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.003868904687499999
# Epoch: 7 cost time: 1.5579838752746582
# Epoch: 7, Steps: 50 | Train Loss: 0.9128071 Vali Loss: 1.9297677 Test Loss: 6.1905122
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 0.003675459453124999
# Epoch: 8 cost time: 1.5574331283569336
# Epoch: 8, Steps: 50 | Train Loss: 0.9080863 Vali Loss: 1.8479068 Test Loss: 7.1677766
# EarlyStopping counter: 3 out of 3
# Early stopping
# 1829 1969
# dlinear-media-lb-112-0.7-1.0 trained for 12.492811918258667
# training TX_2 + HOUSEHOLD_1
# Use GPU: cuda:0
# kernel size:
# 0 1358
# 1246 1941
# 1829 1969
# Model(
#   (decompsition): series_decomp(
#     (moving_avg): MovingMedian()
#   )
#   (Linear_Seasonal): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Trend): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Decoder): Linear(in_features=112, out_features=28, bias=True)
# )
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# FLOPs:  1053696.0
# params:  6328.0
# Trainable parameters:  9492
# !!!!!!!!!!!!!!learning rate!!!!!!!!!!!!!!!
# 0.005
# Epoch: 1 cost time: 1.5376482009887695
# Epoch: 1, Steps: 50 | Train Loss: 0.3915366 Vali Loss: 0.3289096 Test Loss: 15.6094503
# Validation loss decreased (inf --> 0.328910).  Saving model ...
# Updating learning rate to 0.005
# Epoch: 2 cost time: 1.5526220798492432
# Epoch: 2, Steps: 50 | Train Loss: 0.3384719 Vali Loss: 0.3286581 Test Loss: 16.1910114
# Validation loss decreased (0.328910 --> 0.328658).  Saving model ...
# Updating learning rate to 0.00475
# Epoch: 3 cost time: 1.5908992290496826
# Epoch: 3, Steps: 50 | Train Loss: 0.3296324 Vali Loss: 0.3438761 Test Loss: 14.8710461
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.0045125
# Epoch: 4 cost time: 1.4957797527313232
# Epoch: 4, Steps: 50 | Train Loss: 0.3244732 Vali Loss: 0.3342662 Test Loss: 16.4662533
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 0.004286875
# Epoch: 5 cost time: 1.58235502243042
# Epoch: 5, Steps: 50 | Train Loss: 0.3218887 Vali Loss: 0.3477878 Test Loss: 15.1575623
# EarlyStopping counter: 3 out of 3
# Early stopping
# 1829 1969
# dlinear-media-lb-112-0.7-1.0 trained for 7.7593042850494385
# training TX_2 + HOUSEHOLD_2
# Use GPU: cuda:0
# kernel size:
# 0 1358
# 1246 1941
# 1829 1969
# Model(
#   (decompsition): series_decomp(
#     (moving_avg): MovingMedian()
#   )
#   (Linear_Seasonal): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Trend): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Decoder): Linear(in_features=112, out_features=28, bias=True)
# )
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# FLOPs:  1053696.0
# params:  6328.0
# Trainable parameters:  9492
# !!!!!!!!!!!!!!learning rate!!!!!!!!!!!!!!!
# 0.005
# Epoch: 1 cost time: 1.4941256046295166
# Epoch: 1, Steps: 50 | Train Loss: 0.5593660 Vali Loss: 0.8247345 Test Loss: 26.4655724
# Validation loss decreased (inf --> 0.824735).  Saving model ...
# Updating learning rate to 0.005
# Epoch: 2 cost time: 1.5761616230010986
# Epoch: 2, Steps: 50 | Train Loss: 0.4872278 Vali Loss: 0.7952169 Test Loss: 28.4187737
# Validation loss decreased (0.824735 --> 0.795217).  Saving model ...
# Updating learning rate to 0.00475
# Epoch: 3 cost time: 1.5869758129119873
# Epoch: 3, Steps: 50 | Train Loss: 0.4746610 Vali Loss: 0.8040278 Test Loss: 29.0356579
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.0045125
# Epoch: 4 cost time: 1.4788763523101807
# Epoch: 4, Steps: 50 | Train Loss: 0.4630324 Vali Loss: 0.8295559 Test Loss: 26.4414272
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 0.004286875
# Epoch: 5 cost time: 1.5718090534210205
# Epoch: 5, Steps: 50 | Train Loss: 0.4607842 Vali Loss: 0.7687824 Test Loss: 31.4927998
# Validation loss decreased (0.795217 --> 0.768782).  Saving model ...
# Updating learning rate to 0.00407253125
# Epoch: 6 cost time: 1.5625388622283936
# Epoch: 6, Steps: 50 | Train Loss: 0.4552524 Vali Loss: 0.8079606 Test Loss: 28.2206821
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.003868904687499999
# Epoch: 7 cost time: 1.5413002967834473
# Epoch: 7, Steps: 50 | Train Loss: 0.4538160 Vali Loss: 0.8396192 Test Loss: 27.9076138
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 0.003675459453124999
# Epoch: 8 cost time: 1.5270271301269531
# Epoch: 8, Steps: 50 | Train Loss: 0.4495123 Vali Loss: 0.7787588 Test Loss: 30.4170494
# EarlyStopping counter: 3 out of 3
# Early stopping
# 1829 1969
# dlinear-media-lb-112-0.7-1.0 trained for 12.338814735412598
# training TX_2 + FOODS_1
# Use GPU: cuda:0
# kernel size:
# 0 1358
# 1246 1941
# 1829 1969
# Model(
#   (decompsition): series_decomp(
#     (moving_avg): MovingMedian()
#   )
#   (Linear_Seasonal): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Trend): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Decoder): Linear(in_features=112, out_features=28, bias=True)
# )
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# FLOPs:  1053696.0
# params:  6328.0
# Trainable parameters:  9492
# !!!!!!!!!!!!!!learning rate!!!!!!!!!!!!!!!
# 0.005
# Epoch: 1 cost time: 1.5277857780456543
# Epoch: 1, Steps: 50 | Train Loss: 0.4888162 Vali Loss: 0.3872558 Test Loss: 9.4597731
# Validation loss decreased (inf --> 0.387256).  Saving model ...
# Updating learning rate to 0.005
# Epoch: 2 cost time: 1.5783841609954834
# Epoch: 2, Steps: 50 | Train Loss: 0.4302186 Vali Loss: 0.3936889 Test Loss: 8.0082693
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.00475
# Epoch: 3 cost time: 1.5757861137390137
# Epoch: 3, Steps: 50 | Train Loss: 0.4174632 Vali Loss: 0.4039602 Test Loss: 8.4179802
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 0.0045125
# Epoch: 4 cost time: 1.5719444751739502
# Epoch: 4, Steps: 50 | Train Loss: 0.4146204 Vali Loss: 0.4018124 Test Loss: 9.0205564
# EarlyStopping counter: 3 out of 3
# Early stopping
# 1829 1969
# dlinear-media-lb-112-0.7-1.0 trained for 6.253900527954102
# training TX_2 + FOODS_2
# Use GPU: cuda:0
# kernel size:
# 0 1358
# 1246 1941
# 1829 1969
# Model(
#   (decompsition): series_decomp(
#     (moving_avg): MovingMedian()
#   )
#   (Linear_Seasonal): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Trend): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Decoder): Linear(in_features=112, out_features=28, bias=True)
# )
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# FLOPs:  1053696.0
# params:  6328.0
# Trainable parameters:  9492
# !!!!!!!!!!!!!!learning rate!!!!!!!!!!!!!!!
# 0.005
# Epoch: 1 cost time: 1.5335414409637451
# Epoch: 1, Steps: 50 | Train Loss: 0.4948465 Vali Loss: 0.3825521 Test Loss: 17.8892727
# Validation loss decreased (inf --> 0.382552).  Saving model ...
# Updating learning rate to 0.005
# Epoch: 2 cost time: 1.5826702117919922
# Epoch: 2, Steps: 50 | Train Loss: 0.4133903 Vali Loss: 0.3824257 Test Loss: 17.9760017
# Validation loss decreased (0.382552 --> 0.382426).  Saving model ...
# Updating learning rate to 0.00475
# Epoch: 3 cost time: 1.6607646942138672
# Epoch: 3, Steps: 50 | Train Loss: 0.4021736 Vali Loss: 0.3958900 Test Loss: 18.0880527
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.0045125
# Epoch: 4 cost time: 1.5801117420196533
# Epoch: 4, Steps: 50 | Train Loss: 0.3972618 Vali Loss: 0.4017006 Test Loss: 17.9984226
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 0.004286875
# Epoch: 5 cost time: 1.5411784648895264
# Epoch: 5, Steps: 50 | Train Loss: 0.3970247 Vali Loss: 0.4036473 Test Loss: 17.4403133
# EarlyStopping counter: 3 out of 3
# Early stopping
# 1829 1969
# dlinear-media-lb-112-0.7-1.0 trained for 7.898266553878784
# training TX_2 + FOODS_3
# Use GPU: cuda:0
# kernel size:
# 0 1358
# 1246 1941
# 1829 1969
# Model(
#   (decompsition): series_decomp(
#     (moving_avg): MovingMedian()
#   )
#   (Linear_Seasonal): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Trend): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Decoder): Linear(in_features=112, out_features=28, bias=True)
# )
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# FLOPs:  1053696.0
# params:  6328.0
# Trainable parameters:  9492
# !!!!!!!!!!!!!!learning rate!!!!!!!!!!!!!!!
# 0.005
# Epoch: 1 cost time: 1.485703468322754
# Epoch: 1, Steps: 50 | Train Loss: 0.4275569 Vali Loss: 0.3689757 Test Loss: 18.7547894
# Validation loss decreased (inf --> 0.368976).  Saving model ...
# Updating learning rate to 0.005
# Epoch: 2 cost time: 1.5607335567474365
# Epoch: 2, Steps: 50 | Train Loss: 0.3585114 Vali Loss: 0.3778120 Test Loss: 18.2697544
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.00475
# Epoch: 3 cost time: 1.6723883152008057
# Epoch: 3, Steps: 50 | Train Loss: 0.3502314 Vali Loss: 0.4039597 Test Loss: 17.9487038
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 0.0045125
# Epoch: 4 cost time: 1.506937026977539
# Epoch: 4, Steps: 50 | Train Loss: 0.3452551 Vali Loss: 0.3787715 Test Loss: 17.9438038
# EarlyStopping counter: 3 out of 3
# Early stopping
# 1829 1969
# dlinear-media-lb-112-0.7-1.0 trained for 6.225762367248535
# training TX_3 + HOBBIES_1
# Use GPU: cuda:0
# kernel size:
# 0 1358
# 1246 1941
# 1829 1969
# Model(
#   (decompsition): series_decomp(
#     (moving_avg): MovingMedian()
#   )
#   (Linear_Seasonal): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Trend): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Decoder): Linear(in_features=112, out_features=28, bias=True)
# )
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# FLOPs:  1053696.0
# params:  6328.0
# Trainable parameters:  9492
# !!!!!!!!!!!!!!learning rate!!!!!!!!!!!!!!!
# 0.005
# Epoch: 1 cost time: 1.6823503971099854
# Epoch: 1, Steps: 50 | Train Loss: 0.6356177 Vali Loss: 0.9599352 Test Loss: 34.4719162
# Validation loss decreased (inf --> 0.959935).  Saving model ...
# Updating learning rate to 0.005
# Epoch: 2 cost time: 1.5626790523529053
# Epoch: 2, Steps: 50 | Train Loss: 0.5742706 Vali Loss: 0.9682912 Test Loss: 38.0395470
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.00475
# Epoch: 3 cost time: 1.5824809074401855
# Epoch: 3, Steps: 50 | Train Loss: 0.5649727 Vali Loss: 1.0980245 Test Loss: 35.8414536
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 0.0045125
# Epoch: 4 cost time: 1.660785436630249
# Epoch: 4, Steps: 50 | Train Loss: 0.5542176 Vali Loss: 0.9397638 Test Loss: 36.8293076
# Validation loss decreased (0.959935 --> 0.939764).  Saving model ...
# Updating learning rate to 0.004286875
# Epoch: 5 cost time: 1.5315735340118408
# Epoch: 5, Steps: 50 | Train Loss: 0.5523154 Vali Loss: 0.9999464 Test Loss: 35.5492630
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.00407253125
# Epoch: 6 cost time: 1.5618383884429932
# Epoch: 6, Steps: 50 | Train Loss: 0.5453010 Vali Loss: 0.9507403 Test Loss: 36.5387001
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 0.003868904687499999
# Epoch: 7 cost time: 1.662353277206421
# Epoch: 7, Steps: 50 | Train Loss: 0.5456994 Vali Loss: 0.9732555 Test Loss: 33.5790253
# EarlyStopping counter: 3 out of 3
# Early stopping
# 1829 1969
# dlinear-media-lb-112-0.7-1.0 trained for 11.24406099319458
# training TX_3 + HOBBIES_2
# Use GPU: cuda:0
# kernel size:
# 0 1358
# 1246 1941
# 1829 1969
# Model(
#   (decompsition): series_decomp(
#     (moving_avg): MovingMedian()
#   )
#   (Linear_Seasonal): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Trend): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Decoder): Linear(in_features=112, out_features=28, bias=True)
# )
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# FLOPs:  1053696.0
# params:  6328.0
# Trainable parameters:  9492
# !!!!!!!!!!!!!!learning rate!!!!!!!!!!!!!!!
# 0.005
# Epoch: 1 cost time: 1.5433151721954346
# Epoch: 1, Steps: 50 | Train Loss: 0.9361266 Vali Loss: 2.9024844 Test Loss: 8.2105255
# Validation loss decreased (inf --> 2.902484).  Saving model ...
# Updating learning rate to 0.005
# Epoch: 2 cost time: 1.6706936359405518
# Epoch: 2, Steps: 50 | Train Loss: 0.8630773 Vali Loss: 3.0477881 Test Loss: 7.5700455
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.00475
# Epoch: 3 cost time: 1.5385043621063232
# Epoch: 3, Steps: 50 | Train Loss: 0.8529088 Vali Loss: 2.8560848 Test Loss: 8.5148392
# Validation loss decreased (2.902484 --> 2.856085).  Saving model ...
# Updating learning rate to 0.0045125
# Epoch: 4 cost time: 1.5517635345458984
# Epoch: 4, Steps: 50 | Train Loss: 0.8495023 Vali Loss: 2.3089314 Test Loss: 10.9585400
# Validation loss decreased (2.856085 --> 2.308931).  Saving model ...
# Updating learning rate to 0.004286875
# Epoch: 5 cost time: 1.6372194290161133
# Epoch: 5, Steps: 50 | Train Loss: 0.8408885 Vali Loss: 2.3986697 Test Loss: 10.3730488
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.00407253125
# Epoch: 6 cost time: 1.5070421695709229
# Epoch: 6, Steps: 50 | Train Loss: 0.8383671 Vali Loss: 2.6039441 Test Loss: 9.7483530
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 0.003868904687499999
# Epoch: 7 cost time: 1.5612843036651611
# Epoch: 7, Steps: 50 | Train Loss: 0.8303253 Vali Loss: 2.7438941 Test Loss: 7.9537344
# EarlyStopping counter: 3 out of 3
# Early stopping
# 1829 1969
# dlinear-media-lb-112-0.7-1.0 trained for 11.009822607040405
# training TX_3 + HOUSEHOLD_1
# Use GPU: cuda:0
# kernel size:
# 0 1358
# 1246 1941
# 1829 1969
# Model(
#   (decompsition): series_decomp(
#     (moving_avg): MovingMedian()
#   )
#   (Linear_Seasonal): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Trend): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Decoder): Linear(in_features=112, out_features=28, bias=True)
# )
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# FLOPs:  1053696.0
# params:  6328.0
# Trainable parameters:  9492
# !!!!!!!!!!!!!!learning rate!!!!!!!!!!!!!!!
# 0.005
# Epoch: 1 cost time: 1.5807406902313232
# Epoch: 1, Steps: 50 | Train Loss: 0.3135699 Vali Loss: 0.4636889 Test Loss: 19.9482937
# Validation loss decreased (inf --> 0.463689).  Saving model ...
# Updating learning rate to 0.005
# Epoch: 2 cost time: 1.5897042751312256
# Epoch: 2, Steps: 50 | Train Loss: 0.2571803 Vali Loss: 0.4590020 Test Loss: 19.2108021
# Validation loss decreased (0.463689 --> 0.459002).  Saving model ...
# Updating learning rate to 0.00475
# Epoch: 3 cost time: 1.6632490158081055
# Epoch: 3, Steps: 50 | Train Loss: 0.2545715 Vali Loss: 0.4804066 Test Loss: 21.1341572
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.0045125
# Epoch: 4 cost time: 1.63088059425354
# Epoch: 4, Steps: 50 | Train Loss: 0.2509224 Vali Loss: 0.4736780 Test Loss: 20.7519646
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 0.004286875
# Epoch: 5 cost time: 1.5984113216400146
# Epoch: 5, Steps: 50 | Train Loss: 0.2469842 Vali Loss: 0.4705872 Test Loss: 20.6645794
# EarlyStopping counter: 3 out of 3
# Early stopping
# 1829 1969
# dlinear-media-lb-112-0.7-1.0 trained for 8.062985897064209
# training TX_3 + HOUSEHOLD_2
# Use GPU: cuda:0
# kernel size:
# 0 1358
# 1246 1941
# 1829 1969
# Model(
#   (decompsition): series_decomp(
#     (moving_avg): MovingMedian()
#   )
#   (Linear_Seasonal): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Trend): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Decoder): Linear(in_features=112, out_features=28, bias=True)
# )
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# FLOPs:  1053696.0
# params:  6328.0
# Trainable parameters:  9492
# !!!!!!!!!!!!!!learning rate!!!!!!!!!!!!!!!
# 0.005
# Epoch: 1 cost time: 1.5949928760528564
# Epoch: 1, Steps: 50 | Train Loss: 0.4555501 Vali Loss: 0.7247772 Test Loss: 39.8455925
# Validation loss decreased (inf --> 0.724777).  Saving model ...
# Updating learning rate to 0.005
# Epoch: 2 cost time: 1.6124651432037354
# Epoch: 2, Steps: 50 | Train Loss: 0.4039624 Vali Loss: 0.7379131 Test Loss: 38.2607193
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.00475
# Epoch: 3 cost time: 1.6849048137664795
# Epoch: 3, Steps: 50 | Train Loss: 0.3939574 Vali Loss: 0.7191861 Test Loss: 38.4118385
# Validation loss decreased (0.724777 --> 0.719186).  Saving model ...
# Updating learning rate to 0.0045125
# Epoch: 4 cost time: 1.606860876083374
# Epoch: 4, Steps: 50 | Train Loss: 0.3836507 Vali Loss: 0.8278583 Test Loss: 32.6373482
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.004286875
# Epoch: 5 cost time: 1.5411436557769775
# Epoch: 5, Steps: 50 | Train Loss: 0.3819167 Vali Loss: 0.7079239 Test Loss: 36.5724144
# Validation loss decreased (0.719186 --> 0.707924).  Saving model ...
# Updating learning rate to 0.00407253125
# Epoch: 6 cost time: 1.712580680847168
# Epoch: 6, Steps: 50 | Train Loss: 0.3770232 Vali Loss: 0.7494625 Test Loss: 40.2015457
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.003868904687499999
# Epoch: 7 cost time: 1.5964596271514893
# Epoch: 7, Steps: 50 | Train Loss: 0.3773490 Vali Loss: 0.7042648 Test Loss: 37.6030884
# Validation loss decreased (0.707924 --> 0.704265).  Saving model ...
# Updating learning rate to 0.003675459453124999
# Epoch: 8 cost time: 1.5871009826660156
# Epoch: 8, Steps: 50 | Train Loss: 0.3722388 Vali Loss: 0.7742218 Test Loss: 34.0735703
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.003491686480468749
# Epoch: 9 cost time: 1.770669937133789
# Epoch: 9, Steps: 50 | Train Loss: 0.3712757 Vali Loss: 0.7207528 Test Loss: 36.6784706
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 0.0033171021564453113
# Epoch: 10 cost time: 1.613361120223999
# Epoch: 10, Steps: 50 | Train Loss: 0.3663640 Vali Loss: 0.7139619 Test Loss: 39.2226181
# EarlyStopping counter: 3 out of 3
# Early stopping
# 1829 1969
# dlinear-media-lb-112-0.7-1.0 trained for 16.320539712905884
# training TX_3 + FOODS_1
# Use GPU: cuda:0
# kernel size:
# 0 1358
# 1246 1941
# 1829 1969
# Model(
#   (decompsition): series_decomp(
#     (moving_avg): MovingMedian()
#   )
#   (Linear_Seasonal): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Trend): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Decoder): Linear(in_features=112, out_features=28, bias=True)
# )
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# FLOPs:  1053696.0
# params:  6328.0
# Trainable parameters:  9492
# !!!!!!!!!!!!!!learning rate!!!!!!!!!!!!!!!
# 0.005
# Epoch: 1 cost time: 1.6657514572143555
# Epoch: 1, Steps: 50 | Train Loss: 0.5206375 Vali Loss: 0.8321850 Test Loss: 15.6332846
# Validation loss decreased (inf --> 0.832185).  Saving model ...
# Updating learning rate to 0.005
# Epoch: 2 cost time: 1.5687282085418701
# Epoch: 2, Steps: 50 | Train Loss: 0.4678227 Vali Loss: 0.7799177 Test Loss: 16.1757183
# Validation loss decreased (0.832185 --> 0.779918).  Saving model ...
# Updating learning rate to 0.00475
# Epoch: 3 cost time: 1.6081347465515137
# Epoch: 3, Steps: 50 | Train Loss: 0.4590154 Vali Loss: 0.8160841 Test Loss: 15.8959150
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.0045125
# Epoch: 4 cost time: 1.7318575382232666
# Epoch: 4, Steps: 50 | Train Loss: 0.4515871 Vali Loss: 0.7984916 Test Loss: 14.8854656
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 0.004286875
# Epoch: 5 cost time: 1.5596840381622314
# Epoch: 5, Steps: 50 | Train Loss: 0.4459479 Vali Loss: 0.8024014 Test Loss: 15.1691542
# EarlyStopping counter: 3 out of 3
# Early stopping
# 1829 1969
# dlinear-media-lb-112-0.7-1.0 trained for 8.134155988693237
# training TX_3 + FOODS_2
# Use GPU: cuda:0
# kernel size:
# 0 1358
# 1246 1941
# 1829 1969
# Model(
#   (decompsition): series_decomp(
#     (moving_avg): MovingMedian()
#   )
#   (Linear_Seasonal): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Trend): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Decoder): Linear(in_features=112, out_features=28, bias=True)
# )
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# FLOPs:  1053696.0
# params:  6328.0
# Trainable parameters:  9492
# !!!!!!!!!!!!!!learning rate!!!!!!!!!!!!!!!
# 0.005
# Epoch: 1 cost time: 1.6380109786987305
# Epoch: 1, Steps: 50 | Train Loss: 0.5830683 Vali Loss: 0.8275876 Test Loss: 24.1610985
# Validation loss decreased (inf --> 0.827588).  Saving model ...
# Updating learning rate to 0.005
# Epoch: 2 cost time: 1.653075933456421
# Epoch: 2, Steps: 50 | Train Loss: 0.4953422 Vali Loss: 0.8165536 Test Loss: 23.7987709
# Validation loss decreased (0.827588 --> 0.816554).  Saving model ...
# Updating learning rate to 0.00475
# Epoch: 3 cost time: 1.547034740447998
# Epoch: 3, Steps: 50 | Train Loss: 0.4816945 Vali Loss: 0.6372909 Test Loss: 31.5907116
# Validation loss decreased (0.816554 --> 0.637291).  Saving model ...
# Updating learning rate to 0.0045125
# Epoch: 4 cost time: 1.7047219276428223
# Epoch: 4, Steps: 50 | Train Loss: 0.4749715 Vali Loss: 0.7413964 Test Loss: 27.3458767
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.004286875
# Epoch: 5 cost time: 1.61263108253479
# Epoch: 5, Steps: 50 | Train Loss: 0.4732990 Vali Loss: 0.8033147 Test Loss: 26.3953419
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 0.00407253125
# Epoch: 6 cost time: 1.6104199886322021
# Epoch: 6, Steps: 50 | Train Loss: 0.4678946 Vali Loss: 0.8116446 Test Loss: 25.9068470
# EarlyStopping counter: 3 out of 3
# Early stopping
# 1829 1969
# dlinear-media-lb-112-0.7-1.0 trained for 9.765894651412964
# training TX_3 + FOODS_3
# Use GPU: cuda:0
# kernel size:
# 0 1358
# 1246 1941
# 1829 1969
# Model(
#   (decompsition): series_decomp(
#     (moving_avg): MovingMedian()
#   )
#   (Linear_Seasonal): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Trend): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Decoder): Linear(in_features=112, out_features=28, bias=True)
# )
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# FLOPs:  1053696.0
# params:  6328.0
# Trainable parameters:  9492
# !!!!!!!!!!!!!!learning rate!!!!!!!!!!!!!!!
# 0.005
# Epoch: 1 cost time: 1.5740795135498047
# Epoch: 1, Steps: 50 | Train Loss: 0.4901345 Vali Loss: 0.4753689 Test Loss: 29.5623035
# Validation loss decreased (inf --> 0.475369).  Saving model ...
# Updating learning rate to 0.005
# Epoch: 2 cost time: 1.5093650817871094
# Epoch: 2, Steps: 50 | Train Loss: 0.4095218 Vali Loss: 0.4688929 Test Loss: 27.6389027
# Validation loss decreased (0.475369 --> 0.468893).  Saving model ...
# Updating learning rate to 0.00475
# Epoch: 3 cost time: 1.5658860206604004
# Epoch: 3, Steps: 50 | Train Loss: 0.4023323 Vali Loss: 0.4806127 Test Loss: 29.6722240
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.0045125
# Epoch: 4 cost time: 1.5722565650939941
# Epoch: 4, Steps: 50 | Train Loss: 0.3941730 Vali Loss: 0.4856480 Test Loss: 28.1016083
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 0.004286875
# Epoch: 5 cost time: 1.5442240238189697
# Epoch: 5, Steps: 50 | Train Loss: 0.3911056 Vali Loss: 0.4732535 Test Loss: 28.5557137
# EarlyStopping counter: 3 out of 3
# Early stopping
# 1829 1969
# dlinear-media-lb-112-0.7-1.0 trained for 7.765811204910278
# training WI_1 + HOBBIES_1
# Use GPU: cuda:0
# kernel size:
# 0 1358
# 1246 1941
# 1829 1969
# Model(
#   (decompsition): series_decomp(
#     (moving_avg): MovingMedian()
#   )
#   (Linear_Seasonal): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Trend): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Decoder): Linear(in_features=112, out_features=28, bias=True)
# )
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# FLOPs:  1053696.0
# params:  6328.0
# Trainable parameters:  9492
# !!!!!!!!!!!!!!learning rate!!!!!!!!!!!!!!!
# 0.005
# Epoch: 1 cost time: 1.5365574359893799
# Epoch: 1, Steps: 50 | Train Loss: 0.5206146 Vali Loss: 0.6513768 Test Loss: 13.9006119
# Validation loss decreased (inf --> 0.651377).  Saving model ...
# Updating learning rate to 0.005
# Epoch: 2 cost time: 1.5785682201385498
# Epoch: 2, Steps: 50 | Train Loss: 0.4469293 Vali Loss: 0.6491079 Test Loss: 13.1646852
# Validation loss decreased (0.651377 --> 0.649108).  Saving model ...
# Updating learning rate to 0.00475
# Epoch: 3 cost time: 1.5713860988616943
# Epoch: 3, Steps: 50 | Train Loss: 0.4372926 Vali Loss: 0.6380901 Test Loss: 13.4893265
# Validation loss decreased (0.649108 --> 0.638090).  Saving model ...
# Updating learning rate to 0.0045125
# Epoch: 4 cost time: 1.5941336154937744
# Epoch: 4, Steps: 50 | Train Loss: 0.4303514 Vali Loss: 0.6241961 Test Loss: 13.5304585
# Validation loss decreased (0.638090 --> 0.624196).  Saving model ...
# Updating learning rate to 0.004286875
# Epoch: 5 cost time: 1.6716361045837402
# Epoch: 5, Steps: 50 | Train Loss: 0.4310096 Vali Loss: 0.6470166 Test Loss: 12.9763851
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.00407253125
# Epoch: 6 cost time: 1.5675067901611328
# Epoch: 6, Steps: 50 | Train Loss: 0.4244456 Vali Loss: 0.6643003 Test Loss: 12.3132496
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 0.003868904687499999
# Epoch: 7 cost time: 1.5748860836029053
# Epoch: 7, Steps: 50 | Train Loss: 0.4229404 Vali Loss: 0.6670799 Test Loss: 13.5787706
# EarlyStopping counter: 3 out of 3
# Early stopping
# 1829 1969
# dlinear-media-lb-112-0.7-1.0 trained for 11.094674348831177
# training WI_1 + HOBBIES_2
# Use GPU: cuda:0
# kernel size:
# 0 1358
# 1246 1941
# 1829 1969
# Model(
#   (decompsition): series_decomp(
#     (moving_avg): MovingMedian()
#   )
#   (Linear_Seasonal): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Trend): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Decoder): Linear(in_features=112, out_features=28, bias=True)
# )
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# FLOPs:  1053696.0
# params:  6328.0
# Trainable parameters:  9492
# !!!!!!!!!!!!!!learning rate!!!!!!!!!!!!!!!
# 0.005
# Epoch: 1 cost time: 1.6018004417419434
# Epoch: 1, Steps: 50 | Train Loss: 0.7853317 Vali Loss: 2.4902909 Test Loss: 10.0921249
# Validation loss decreased (inf --> 2.490291).  Saving model ...
# Updating learning rate to 0.005
# Epoch: 2 cost time: 1.5966556072235107
# Epoch: 2, Steps: 50 | Train Loss: 0.7200125 Vali Loss: 1.9986306 Test Loss: 9.1875696
# Validation loss decreased (2.490291 --> 1.998631).  Saving model ...
# Updating learning rate to 0.00475
# Epoch: 3 cost time: 1.6815693378448486
# Epoch: 3, Steps: 50 | Train Loss: 0.7043128 Vali Loss: 2.0409331 Test Loss: 8.9927320
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.0045125
# Epoch: 4 cost time: 1.5500609874725342
# Epoch: 4, Steps: 50 | Train Loss: 0.6943321 Vali Loss: 1.9607134 Test Loss: 8.5127611
# Validation loss decreased (1.998631 --> 1.960713).  Saving model ...
# Updating learning rate to 0.004286875
# Epoch: 5 cost time: 1.6130187511444092
# Epoch: 5, Steps: 50 | Train Loss: 0.6937790 Vali Loss: 2.1818748 Test Loss: 8.8690271
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.00407253125
# Epoch: 6 cost time: 1.6857044696807861
# Epoch: 6, Steps: 50 | Train Loss: 0.6859264 Vali Loss: 2.0717983 Test Loss: 8.6641073
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 0.003868904687499999
# Epoch: 7 cost time: 1.6389894485473633
# Epoch: 7, Steps: 50 | Train Loss: 0.6831464 Vali Loss: 1.9101460 Test Loss: 8.0752563
# Validation loss decreased (1.960713 --> 1.910146).  Saving model ...
# Updating learning rate to 0.003675459453124999
# Epoch: 8 cost time: 1.6089801788330078
# Epoch: 8, Steps: 50 | Train Loss: 0.6773387 Vali Loss: 2.0058260 Test Loss: 7.9997611
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.003491686480468749
# Epoch: 9 cost time: 1.6361982822418213
# Epoch: 9, Steps: 50 | Train Loss: 0.6699254 Vali Loss: 1.9595485 Test Loss: 8.6509981
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 0.0033171021564453113
# Epoch: 10 cost time: 1.5707623958587646
# Epoch: 10, Steps: 50 | Train Loss: 0.6668114 Vali Loss: 2.2108979 Test Loss: 9.7075958
# EarlyStopping counter: 3 out of 3
# Early stopping
# 1829 1969
# dlinear-media-lb-112-0.7-1.0 trained for 16.18373990058899
# training WI_1 + HOUSEHOLD_1
# Use GPU: cuda:0
# kernel size:
# 0 1358
# 1246 1941
# 1829 1969
# Model(
#   (decompsition): series_decomp(
#     (moving_avg): MovingMedian()
#   )
#   (Linear_Seasonal): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Trend): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Decoder): Linear(in_features=112, out_features=28, bias=True)
# )
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# FLOPs:  1053696.0
# params:  6328.0
# Trainable parameters:  9492
# !!!!!!!!!!!!!!learning rate!!!!!!!!!!!!!!!
# 0.005
# Epoch: 1 cost time: 1.6678476333618164
# Epoch: 1, Steps: 50 | Train Loss: 0.3800442 Vali Loss: 0.6060407 Test Loss: 21.0475712
# Validation loss decreased (inf --> 0.606041).  Saving model ...
# Updating learning rate to 0.005
# Epoch: 2 cost time: 1.6505153179168701
# Epoch: 2, Steps: 50 | Train Loss: 0.3212114 Vali Loss: 0.6080816 Test Loss: 19.3840141
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.00475
# Epoch: 3 cost time: 1.5493659973144531
# Epoch: 3, Steps: 50 | Train Loss: 0.3088354 Vali Loss: 0.6596808 Test Loss: 17.6323738
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 0.0045125
# Epoch: 4 cost time: 1.6782162189483643
# Epoch: 4, Steps: 50 | Train Loss: 0.3028693 Vali Loss: 0.6484823 Test Loss: 18.4759502
# EarlyStopping counter: 3 out of 3
# Early stopping
# 1829 1969
# dlinear-media-lb-112-0.7-1.0 trained for 6.545945167541504
# training WI_1 + HOUSEHOLD_2
# Use GPU: cuda:0
# kernel size:
# 0 1358
# 1246 1941
# 1829 1969
# Model(
#   (decompsition): series_decomp(
#     (moving_avg): MovingMedian()
#   )
#   (Linear_Seasonal): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Trend): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Decoder): Linear(in_features=112, out_features=28, bias=True)
# )
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# FLOPs:  1053696.0
# params:  6328.0
# Trainable parameters:  9492
# !!!!!!!!!!!!!!learning rate!!!!!!!!!!!!!!!
# 0.005
# Epoch: 1 cost time: 1.5556750297546387
# Epoch: 1, Steps: 50 | Train Loss: 0.6271389 Vali Loss: 0.7508750 Test Loss: 25.5368748
# Validation loss decreased (inf --> 0.750875).  Saving model ...
# Updating learning rate to 0.005
# Epoch: 2 cost time: 1.7323129177093506
# Epoch: 2, Steps: 50 | Train Loss: 0.5259044 Vali Loss: 0.7602851 Test Loss: 25.3495293
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.00475
# Epoch: 3 cost time: 1.5769526958465576
# Epoch: 3, Steps: 50 | Train Loss: 0.5133970 Vali Loss: 0.8674740 Test Loss: 24.1222439
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 0.0045125
# Epoch: 4 cost time: 1.5961852073669434
# Epoch: 4, Steps: 50 | Train Loss: 0.5072526 Vali Loss: 0.7529408 Test Loss: 25.7661476
# EarlyStopping counter: 3 out of 3
# Early stopping
# 1829 1969
# dlinear-media-lb-112-0.7-1.0 trained for 6.46112585067749
# training WI_1 + FOODS_1
# Use GPU: cuda:0
# kernel size:
# 0 1358
# 1246 1941
# 1829 1969
# Model(
#   (decompsition): series_decomp(
#     (moving_avg): MovingMedian()
#   )
#   (Linear_Seasonal): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Trend): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Decoder): Linear(in_features=112, out_features=28, bias=True)
# )
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# FLOPs:  1053696.0
# params:  6328.0
# Trainable parameters:  9492
# !!!!!!!!!!!!!!learning rate!!!!!!!!!!!!!!!
# 0.005
# Epoch: 1 cost time: 1.6176846027374268
# Epoch: 1, Steps: 50 | Train Loss: 0.7122282 Vali Loss: 0.9853028 Test Loss: 19.0951595
# Validation loss decreased (inf --> 0.985303).  Saving model ...
# Updating learning rate to 0.005
# Epoch: 2 cost time: 1.6001906394958496
# Epoch: 2, Steps: 50 | Train Loss: 0.6536210 Vali Loss: 1.0051452 Test Loss: 19.7867756
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.00475
# Epoch: 3 cost time: 1.6877257823944092
# Epoch: 3, Steps: 50 | Train Loss: 0.6365183 Vali Loss: 1.0184397 Test Loss: 18.9308262
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 0.0045125
# Epoch: 4 cost time: 1.576810359954834
# Epoch: 4, Steps: 50 | Train Loss: 0.6299025 Vali Loss: 1.0579420 Test Loss: 18.2202682
# EarlyStopping counter: 3 out of 3
# Early stopping
# 1829 1969
# dlinear-media-lb-112-0.7-1.0 trained for 6.4824113845825195
# training WI_1 + FOODS_2
# Use GPU: cuda:0
# kernel size:
# 0 1358
# 1246 1941
# 1829 1969
# Model(
#   (decompsition): series_decomp(
#     (moving_avg): MovingMedian()
#   )
#   (Linear_Seasonal): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Trend): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Decoder): Linear(in_features=112, out_features=28, bias=True)
# )
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# FLOPs:  1053696.0
# params:  6328.0
# Trainable parameters:  9492
# !!!!!!!!!!!!!!learning rate!!!!!!!!!!!!!!!
# 0.005
# Epoch: 1 cost time: 1.680854320526123
# Epoch: 1, Steps: 50 | Train Loss: 0.2160259 Vali Loss: 0.3653016 Test Loss: 13.9379578
# Validation loss decreased (inf --> 0.365302).  Saving model ...
# Updating learning rate to 0.005
# Epoch: 2 cost time: 1.5738756656646729
# Epoch: 2, Steps: 50 | Train Loss: 0.1612614 Vali Loss: 0.4459464 Test Loss: 12.4053583
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.00475
# Epoch: 3 cost time: 1.6192200183868408
# Epoch: 3, Steps: 50 | Train Loss: 0.1633895 Vali Loss: 0.3767364 Test Loss: 15.9542522
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 0.0045125
# Epoch: 4 cost time: 1.665475845336914
# Epoch: 4, Steps: 50 | Train Loss: 0.1578723 Vali Loss: 0.3944389 Test Loss: 13.1083822
# EarlyStopping counter: 3 out of 3
# Early stopping
# 1829 1969
# dlinear-media-lb-112-0.7-1.0 trained for 6.539425849914551
# training WI_1 + FOODS_3
# Use GPU: cuda:0
# kernel size:
# 0 1358
# 1246 1941
# 1829 1969
# Model(
#   (decompsition): series_decomp(
#     (moving_avg): MovingMedian()
#   )
#   (Linear_Seasonal): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Trend): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Decoder): Linear(in_features=112, out_features=28, bias=True)
# )
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# FLOPs:  1053696.0
# params:  6328.0
# Trainable parameters:  9492
# !!!!!!!!!!!!!!learning rate!!!!!!!!!!!!!!!
# 0.005
# Epoch: 1 cost time: 1.5913069248199463
# Epoch: 1, Steps: 50 | Train Loss: 0.2482665 Vali Loss: 0.2722149 Test Loss: 16.2320709
# Validation loss decreased (inf --> 0.272215).  Saving model ...
# Updating learning rate to 0.005
# Epoch: 2 cost time: 1.747312307357788
# Epoch: 2, Steps: 50 | Train Loss: 0.2058376 Vali Loss: 0.2795827 Test Loss: 15.3449392
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.00475
# ...
# Updating learning rate to 0.00475
# Epoch: 3 cost time: 1.8646292686462402
# Epoch: 3, Steps: 62 | Train Loss: 0.4408418 Vali Loss: 0.7927313 Test Loss: 18.5213318
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.0045125
# Epoch: 4 cost time: 1.922412633895874
# Epoch: 4, Steps: 62 | Train Loss: 0.4360925 Vali Loss: 0.7942402 Test Loss: 18.6602459
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 0.004286875
# Epoch: 5 cost time: 1.982048749923706
# Epoch: 5, Steps: 62 | Train Loss: 0.4297620 Vali Loss: 0.7821231 Test Loss: 19.6187096
# EarlyStopping counter: 3 out of 3
# Early stopping
# 1829 1969
# dlinear-media-lb-112-0.85-1.0 trained for 9.494415998458862
# training WI_2 + FOODS_2
# Use GPU: cuda:0
# kernel size:
# 0 1649
# 1537 1941
# 1829 1969
# Model(
#   (decompsition): series_decomp(
#     (moving_avg): MovingMedian()
#   )
#   (Linear_Seasonal): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Trend): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Decoder): Linear(in_features=112, out_features=28, bias=True)
# )
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# FLOPs:  1053696.0
# params:  6328.0
# Trainable parameters:  9492
# !!!!!!!!!!!!!!learning rate!!!!!!!!!!!!!!!
# 0.005
# Epoch: 1 cost time: 1.883910894393921
# Epoch: 1, Steps: 62 | Train Loss: 0.2359443 Vali Loss: 0.4564835 Test Loss: 18.5270195
# Validation loss decreased (inf --> 0.456483).  Saving model ...
# Updating learning rate to 0.005
# Epoch: 2 cost time: 1.8507635593414307
# Epoch: 2, Steps: 62 | Train Loss: 0.1851626 Vali Loss: 0.4475351 Test Loss: 18.0686665
# Validation loss decreased (0.456483 --> 0.447535).  Saving model ...
# Updating learning rate to 0.00475
# Epoch: 3 cost time: 1.8928899765014648
# Epoch: 3, Steps: 62 | Train Loss: 0.1771154 Vali Loss: 0.5490511 Test Loss: 16.2431927
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.0045125
# Epoch: 4 cost time: 2.1093389987945557
# Epoch: 4, Steps: 62 | Train Loss: 0.1724825 Vali Loss: 0.4674270 Test Loss: 17.2177849
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 0.004286875
# Epoch: 5 cost time: 1.8645029067993164
# Epoch: 5, Steps: 62 | Train Loss: 0.1711246 Vali Loss: 0.5082057 Test Loss: 16.1904526
# EarlyStopping counter: 3 out of 3
# Early stopping
# 1829 1969
# dlinear-media-lb-112-0.85-1.0 trained for 9.601406335830688
# training WI_2 + FOODS_3
# Use GPU: cuda:0
# kernel size:
# 0 1649
# 1537 1941
# 1829 1969
# Model(
#   (decompsition): series_decomp(
#     (moving_avg): MovingMedian()
#   )
#   (Linear_Seasonal): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Trend): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Decoder): Linear(in_features=112, out_features=28, bias=True)
# )
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# FLOPs:  1053696.0
# params:  6328.0
# Trainable parameters:  9492
# !!!!!!!!!!!!!!learning rate!!!!!!!!!!!!!!!
# 0.005
# Epoch: 1 cost time: 1.9170787334442139
# Epoch: 1, Steps: 62 | Train Loss: 0.2971758 Vali Loss: 0.2892808 Test Loss: 14.6224909
# Validation loss decreased (inf --> 0.289281).  Saving model ...
# Updating learning rate to 0.005
# Epoch: 2 cost time: 1.8751845359802246
# Epoch: 2, Steps: 62 | Train Loss: 0.2456072 Vali Loss: 0.2820526 Test Loss: 14.6112366
# Validation loss decreased (0.289281 --> 0.282053).  Saving model ...
# Updating learning rate to 0.00475
# Epoch: 3 cost time: 2.0018296241760254
# Epoch: 3, Steps: 62 | Train Loss: 0.2392712 Vali Loss: 0.2832222 Test Loss: 15.0138302
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.0045125
# Epoch: 4 cost time: 1.849780797958374
# Epoch: 4, Steps: 62 | Train Loss: 0.2395242 Vali Loss: 0.2843337 Test Loss: 15.4007177
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 0.004286875
# Epoch: 5 cost time: 1.9113781452178955
# Epoch: 5, Steps: 62 | Train Loss: 0.2335382 Vali Loss: 0.2824224 Test Loss: 15.1480322
# EarlyStopping counter: 3 out of 3
# Early stopping
# 1829 1969
# dlinear-media-lb-112-0.85-1.0 trained for 9.555251836776733
# training WI_3 + HOBBIES_1
# Use GPU: cuda:0
# kernel size:
# 0 1649
# 1537 1941
# 1829 1969
# Model(
#   (decompsition): series_decomp(
#     (moving_avg): MovingMedian()
#   )
#   (Linear_Seasonal): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Trend): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Decoder): Linear(in_features=112, out_features=28, bias=True)
# )
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# FLOPs:  1053696.0
# params:  6328.0
# Trainable parameters:  9492
# !!!!!!!!!!!!!!learning rate!!!!!!!!!!!!!!!
# 0.005
# Epoch: 1 cost time: 1.8720955848693848
# Epoch: 1, Steps: 62 | Train Loss: 0.7760972 Vali Loss: 0.7140546 Test Loss: 16.0622902
# Validation loss decreased (inf --> 0.714055).  Saving model ...
# Updating learning rate to 0.005
# Epoch: 2 cost time: 2.0021023750305176
# Epoch: 2, Steps: 62 | Train Loss: 0.7126551 Vali Loss: 0.7245851 Test Loss: 16.5364742
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.00475
# Epoch: 3 cost time: 1.950838565826416
# Epoch: 3, Steps: 62 | Train Loss: 0.7090200 Vali Loss: 0.7163769 Test Loss: 17.4900799
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 0.0045125
# Epoch: 4 cost time: 1.8243353366851807
# Epoch: 4, Steps: 62 | Train Loss: 0.7001533 Vali Loss: 0.7232656 Test Loss: 17.0083904
# EarlyStopping counter: 3 out of 3
# Early stopping
# 1829 1969
# dlinear-media-lb-112-0.85-1.0 trained for 7.649371862411499
# training WI_3 + HOBBIES_2
# Use GPU: cuda:0
# kernel size:
# 0 1649
# 1537 1941
# 1829 1969
# Model(
#   (decompsition): series_decomp(
#     (moving_avg): MovingMedian()
#   )
#   (Linear_Seasonal): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Trend): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Decoder): Linear(in_features=112, out_features=28, bias=True)
# )
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# FLOPs:  1053696.0
# params:  6328.0
# Trainable parameters:  9492
# !!!!!!!!!!!!!!learning rate!!!!!!!!!!!!!!!
# 0.005
# Epoch: 1 cost time: 1.8337602615356445
# Epoch: 1, Steps: 62 | Train Loss: 1.0017641 Vali Loss: 1.6648690 Test Loss: 9.9285402
# Validation loss decreased (inf --> 1.664869).  Saving model ...
# Updating learning rate to 0.005
# Epoch: 2 cost time: 1.9245703220367432
# Epoch: 2, Steps: 62 | Train Loss: 0.9361383 Vali Loss: 1.6806496 Test Loss: 10.0564947
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.00475
# Epoch: 3 cost time: 1.9210209846496582
# Epoch: 3, Steps: 62 | Train Loss: 0.9241562 Vali Loss: 1.6790348 Test Loss: 9.4917574
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 0.0045125
# Epoch: 4 cost time: 1.8705904483795166
# Epoch: 4, Steps: 62 | Train Loss: 0.9139195 Vali Loss: 1.6747950 Test Loss: 11.7812672
# EarlyStopping counter: 3 out of 3
# Early stopping
# 1829 1969
# dlinear-media-lb-112-0.85-1.0 trained for 7.5499420166015625
# training WI_3 + HOUSEHOLD_1
# Use GPU: cuda:0
# kernel size:
# 0 1649
# 1537 1941
# 1829 1969
# Model(
#   (decompsition): series_decomp(
#     (moving_avg): MovingMedian()
#   )
#   (Linear_Seasonal): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Trend): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Decoder): Linear(in_features=112, out_features=28, bias=True)
# )
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# FLOPs:  1053696.0
# params:  6328.0
# Trainable parameters:  9492
# !!!!!!!!!!!!!!learning rate!!!!!!!!!!!!!!!
# 0.005
# Epoch: 1 cost time: 1.9734623432159424
# Epoch: 1, Steps: 62 | Train Loss: 0.4501895 Vali Loss: 0.4518175 Test Loss: 18.2369576
# Validation loss decreased (inf --> 0.451818).  Saving model ...
# Updating learning rate to 0.005
# Epoch: 2 cost time: 1.978973388671875
# Epoch: 2, Steps: 62 | Train Loss: 0.3679392 Vali Loss: 0.4831649 Test Loss: 16.7584686
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.00475
# Epoch: 3 cost time: 1.9067726135253906
# Epoch: 3, Steps: 62 | Train Loss: 0.3653213 Vali Loss: 0.4695763 Test Loss: 18.7905159
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 0.0045125
# Epoch: 4 cost time: 1.9991261959075928
# Epoch: 4, Steps: 62 | Train Loss: 0.3576541 Vali Loss: 0.4688862 Test Loss: 18.7252369
# EarlyStopping counter: 3 out of 3
# Early stopping
# 1829 1969
# dlinear-media-lb-112-0.85-1.0 trained for 7.858334541320801
# training WI_3 + HOUSEHOLD_2
# Use GPU: cuda:0
# kernel size:
# 0 1649
# 1537 1941
# 1829 1969
# Model(
#   (decompsition): series_decomp(
#     (moving_avg): MovingMedian()
#   )
#   (Linear_Seasonal): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Trend): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Decoder): Linear(in_features=112, out_features=28, bias=True)
# )
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# FLOPs:  1053696.0
# params:  6328.0
# Trainable parameters:  9492
# !!!!!!!!!!!!!!learning rate!!!!!!!!!!!!!!!
# 0.005
# Epoch: 1 cost time: 1.9010982513427734
# Epoch: 1, Steps: 62 | Train Loss: 0.5327430 Vali Loss: 0.9343231 Test Loss: 29.3478031
# Validation loss decreased (inf --> 0.934323).  Saving model ...
# Updating learning rate to 0.005
# Epoch: 2 cost time: 2.0315840244293213
# Epoch: 2, Steps: 62 | Train Loss: 0.4691537 Vali Loss: 0.9002594 Test Loss: 40.1750259
# Validation loss decreased (0.934323 --> 0.900259).  Saving model ...
# Updating learning rate to 0.00475
# Epoch: 3 cost time: 1.9187514781951904
# Epoch: 3, Steps: 62 | Train Loss: 0.4605678 Vali Loss: 0.9313423 Test Loss: 32.5364990
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.0045125
# Epoch: 4 cost time: 1.8869264125823975
# Epoch: 4, Steps: 62 | Train Loss: 0.4575578 Vali Loss: 0.9364210 Test Loss: 36.8313026
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 0.004286875
# Epoch: 5 cost time: 2.1438839435577393
# Epoch: 5, Steps: 62 | Train Loss: 0.4526558 Vali Loss: 0.8836496 Test Loss: 38.4041710
# Validation loss decreased (0.900259 --> 0.883650).  Saving model ...
# Updating learning rate to 0.00407253125
# Epoch: 6 cost time: 1.8759853839874268
# Epoch: 6, Steps: 62 | Train Loss: 0.4477653 Vali Loss: 0.8956714 Test Loss: 32.4385567
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.003868904687499999
# Epoch: 7 cost time: 1.922314167022705
# Epoch: 7, Steps: 62 | Train Loss: 0.4470109 Vali Loss: 0.9266821 Test Loss: 32.4394455
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 0.003675459453124999
# Epoch: 8 cost time: 1.9983155727386475
# Epoch: 8, Steps: 62 | Train Loss: 0.4445224 Vali Loss: 0.8924201 Test Loss: 33.9869576
# EarlyStopping counter: 3 out of 3
# Early stopping
# 1829 1969
# dlinear-media-lb-112-0.85-1.0 trained for 15.678859233856201
# training WI_3 + FOODS_1
# Use GPU: cuda:0
# kernel size:
# 0 1649
# 1537 1941
# 1829 1969
# Model(
#   (decompsition): series_decomp(
#     (moving_avg): MovingMedian()
#   )
#   (Linear_Seasonal): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Trend): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Decoder): Linear(in_features=112, out_features=28, bias=True)
# )
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# FLOPs:  1053696.0
# params:  6328.0
# Trainable parameters:  9492
# !!!!!!!!!!!!!!learning rate!!!!!!!!!!!!!!!
# 0.005
# Epoch: 1 cost time: 2.0187511444091797
# Epoch: 1, Steps: 62 | Train Loss: 0.5686159 Vali Loss: 0.7977995 Test Loss: 17.1315651
# Validation loss decreased (inf --> 0.797799).  Saving model ...
# Updating learning rate to 0.005
# Epoch: 2 cost time: 1.8789536952972412
# Epoch: 2, Steps: 62 | Train Loss: 0.5128476 Vali Loss: 0.7726279 Test Loss: 16.5538521
# Validation loss decreased (0.797799 --> 0.772628).  Saving model ...
# Updating learning rate to 0.00475
# Epoch: 3 cost time: 1.9383432865142822
# Epoch: 3, Steps: 62 | Train Loss: 0.5018104 Vali Loss: 0.7853646 Test Loss: 18.2914925
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.0045125
# Epoch: 4 cost time: 1.925471544265747
# Epoch: 4, Steps: 62 | Train Loss: 0.4971720 Vali Loss: 0.8218704 Test Loss: 16.3827457
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 0.004286875
# Epoch: 5 cost time: 1.8654401302337646
# Epoch: 5, Steps: 62 | Train Loss: 0.4879168 Vali Loss: 0.7761341 Test Loss: 17.6428928
# EarlyStopping counter: 3 out of 3
# Early stopping
# 1829 1969
# dlinear-media-lb-112-0.85-1.0 trained for 9.626959800720215
# training WI_3 + FOODS_2
# Use GPU: cuda:0
# kernel size:
# 0 1649
# 1537 1941
# 1829 1969
# Model(
#   (decompsition): series_decomp(
#     (moving_avg): MovingMedian()
#   )
#   (Linear_Seasonal): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Trend): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Decoder): Linear(in_features=112, out_features=28, bias=True)
# )
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# FLOPs:  1053696.0
# params:  6328.0
# Trainable parameters:  9492
# !!!!!!!!!!!!!!learning rate!!!!!!!!!!!!!!!
# 0.005
# Epoch: 1 cost time: 1.8740758895874023
# Epoch: 1, Steps: 62 | Train Loss: 0.3572534 Vali Loss: 0.3598823 Test Loss: 13.7681017
# Validation loss decreased (inf --> 0.359882).  Saving model ...
# Updating learning rate to 0.005
# Epoch: 2 cost time: 1.8247673511505127
# Epoch: 2, Steps: 62 | Train Loss: 0.2920179 Vali Loss: 0.3462951 Test Loss: 14.4803381
# Validation loss decreased (0.359882 --> 0.346295).  Saving model ...
# Updating learning rate to 0.00475
# Epoch: 3 cost time: 2.034053325653076
# Epoch: 3, Steps: 62 | Train Loss: 0.2829699 Vali Loss: 0.3614502 Test Loss: 13.1344099
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.0045125
# Epoch: 4 cost time: 1.876258373260498
# Epoch: 4, Steps: 62 | Train Loss: 0.2783959 Vali Loss: 0.3491721 Test Loss: 15.2463179
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 0.004286875
# Epoch: 5 cost time: 1.9867658615112305
# Epoch: 5, Steps: 62 | Train Loss: 0.2762862 Vali Loss: 0.3622347 Test Loss: 13.4182158
# EarlyStopping counter: 3 out of 3
# Early stopping
# 1829 1969
# dlinear-media-lb-112-0.85-1.0 trained for 9.59592080116272
# training WI_3 + FOODS_3
# Use GPU: cuda:0
# kernel size:
# 0 1649
# 1537 1941
# 1829 1969
# Model(
#   (decompsition): series_decomp(
#     (moving_avg): MovingMedian()
#   )
#   (Linear_Seasonal): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Trend): Linear(in_features=112, out_features=28, bias=True)
#   (Linear_Decoder): Linear(in_features=112, out_features=28, bias=True)
# )
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# FLOPs:  1053696.0
# params:  6328.0
# Trainable parameters:  9492
# !!!!!!!!!!!!!!learning rate!!!!!!!!!!!!!!!
# 0.005
# Epoch: 1 cost time: 1.9157843589782715
# Epoch: 1, Steps: 62 | Train Loss: 0.3958965 Vali Loss: 0.2749498 Test Loss: 16.6436996
# Validation loss decreased (inf --> 0.274950).  Saving model ...
# Updating learning rate to 0.005
# Epoch: 2 cost time: 2.06803822517395
# Epoch: 2, Steps: 62 | Train Loss: 0.3222309 Vali Loss: 0.2584152 Test Loss: 15.1701593
# Validation loss decreased (0.274950 --> 0.258415).  Saving model ...
# Updating learning rate to 0.00475
# Epoch: 3 cost time: 1.9283690452575684
# Epoch: 3, Steps: 62 | Train Loss: 0.3182044 Vali Loss: 0.2650832 Test Loss: 16.1861248
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.0045125
# Epoch: 4 cost time: 1.9224750995635986
# Epoch: 4, Steps: 62 | Train Loss: 0.3170816 Vali Loss: 0.2568322 Test Loss: 16.7178860
# Validation loss decreased (0.258415 --> 0.256832).  Saving model ...
# Updating learning rate to 0.004286875
# Epoch: 5 cost time: 1.9052612781524658
# Epoch: 5, Steps: 62 | Train Loss: 0.3075550 Vali Loss: 0.2651558 Test Loss: 15.7032118
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.00407253125
# Epoch: 6 cost time: 1.9804515838623047
# Epoch: 6, Steps: 62 | Train Loss: 0.3052141 Vali Loss: 0.2582867 Test Loss: 16.7301331
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 0.003868904687499999
# Epoch: 7 cost time: 2.064368963241577
# Epoch: 7, Steps: 62 | Train Loss: 0.3039822 Vali Loss: 0.2629650 Test Loss: 16.3834667
# EarlyStopping counter: 3 out of 3
# Early stopping
# 1829 1969
# dlinear-media-lb-112-0.85-1.0 trained for 13.784748554229736

# %%
model_training_times_df = pd.DataFrame(model_training_times, columns=['name', 'duration'])
model_training_times_df.to_csv(model_training_time_path + 'model_training_times.csv', index=False)
model_training_times_df
# Out:
#                             name    duration
# 0   dlinear-media-lb-112-0.7-1.0  617.031081
# 1  dlinear-media-lb-112-0.85-1.0  769.694833
